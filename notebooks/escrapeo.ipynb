# %%
import pandas as pd
import requests as rq
import numpy as np
import pyarrow
from bs4 import BeautifulSoup as bs
import os
from dotenv import load_dotenv
import time
from datetime import datetime
import sys #permite navegar por el sistema
sys.path.append("../") #solo aplica al soporte
import src.escrapeo as es

# %%
load_dotenv()
# Out:
# True

# %%
RUTA_SERVICE = os.getenv("RUTA_SERVICE")
URL_ESCRAPEO_INICIAL = os.getenv("URL_ESCRAPEO_INICIAL")

# %%
#Variables 
url_destinos= URL_ESCRAPEO_INICIAL

# %%
# Accedemos a la url
res_destinos=rq.get(url_destinos)
# Comprobamos que tenemos una respuesta correcta
res_destinos.status_code
# Out:
# 200

# %%
# Creamos la sopa
sopa_destinos=bs(res_destinos.content,"html.parser")
sopa_destinos
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Consent Mode de Google, permite hacer un tracking de visitantes activos aunque no acepten las cookies -->
# <!-- Cookie Consent by https://www.FreePrivacyPolicy.com -->
# <script src="/vendor/cookieConsent/cookie-consent.js"></script>
# <script type="text/javascript">
#         document.addEventListener('DOMContentLoaded', function () {
#             cookieconsent.run({ "notice_banner_type": "interstitial", "consent_type": "express", "palette": "light", "language": "es", "website_name": "TUI", "cookies_policy_url": "https://es.tui.com/politica-privacidad" });
#         });
#     </script>
# <!-- End Cookie Consent -->
# <!-- Google Tag Manager -->
# <script cookie-consent="tracking" type="text/plain">
#         (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-54HQHT');
#
#         function prepairQuotation() {
#         console.log(item);
#         console.log(token);
#         var token = '';
#         var link = 'https://reservas-online.es.tui.com/b2b/redirectionDeepLinkQuote.jsf?quoteReference=' + xd.value + '&UP=' + token;
#         document.getElementById('btnEnvio').href = link;
#         }
#     </script>
# <!-- Page hiding snippet (recommended) -->
# <style>
#         .async-hide {
#             /*opacity: 0 !important*/
#         }
#
#         /*.ui-autocomplete-loading {
#             background: url(images/load-loading.gif) no-repeat left center #fff !important;
#             background-size: 40% !important;
#             background-position-x: -72px !important;
#         }*/
#     </style>
# <script cookie-consent="tracking" type="text/plain">
#         (function (a, s, y, n, c, h, i, d, e) {
#         s.className += ' ' + y;
#         h.end = i = function () { s.className = s.className.replace(RegExp(' ?' + y), '') };
#         (a[n] = a[n] || []).hide = h; setTimeout(function () { i(); h.end = null }, c);
#         })(window, document.documentElement, 'async-hide', 'dataLayer', 4000, { 'GTM-54HQHT': true });
#     </script>
# <!-- End Google Tag Manager -->
# <script>
#         var hideMenuSpecialDepartures = false;
#         var hideMenuTrìpTypes = false;
#     </script>
# <script cookie-consent="functionality" src="https://cdn.jsdelivr.net/npm/sweetalert2@9"></script>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="true" name="HandheldFriendly"/>
# <title>Todos los destinos</title>
# <!-- FAV ICON -->
# <link href="/images/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/images/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/images/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/images/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/images/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/images/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/images/favicon/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/images/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- FONT-AWESOME ICON CSS -->
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <!--== ALL CSS FILES ==-->
# <link href="/css/jquery-ui.min.css" rel="stylesheet">
# <link href="/css/style.css?v=1.78.8.020250408174534" rel="stylesheet"/>
# <link href="/css/hero.css?v=1.78.8.020250408174534" rel="stylesheet"/>
# <link href="/css/materialize.css" rel="stylesheet"/><!-- NO tocar ni cambiar de versión, se van a la mierda el diseño-->
# <!-- v2-->
# <link href="/vendor/bootstrap/dist/css/bootstrap.css" rel="stylesheet"> <!-- v3.3.7-->
# <link href="/css/mob.css" rel="stylesheet"/>
# <link href="/css/animate.css" rel="stylesheet"/>
# <link href="/css/iconos-tui.css" rel="stylesheet"/>
# <link href="/vendor/metisMenu/dist/metisMenu.css" rel="stylesheet">
# <link href="/vendor/select2-3.5.2/select2b.css" rel="stylesheet">
# <!-- ==DATATABLES ==-->
# <link href="/vendor/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet">
# <link href="/vendor/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet">
# <link href="/vendor/datatables.net-buttons-bs/css/buttons.bootstrap.min.css" rel="stylesheet">
# <!-- Datetimepicker -->
# <link href="/js/bootstrap-datetimepicker-master/bootstrap-datetimepicker.css" rel="stylesheet">
# <!-- Datepicker -->
# <link href="/js/bootstrap-datepicker-1.9.0-dist/css/bootstrap-datepicker.css" rel="stylesheet">
# <!-- NanoScroller -->
# <link href="/vendor/nanoscroller/css/nanoscroller.min.css" rel="stylesheet">
# <!-- Slick -->
# <link href="/vendor/slick/slick.css" rel="stylesheet">
# <!-- FancyBox -->
# <link href="/vendor/fancybox/jquery.fancybox.css" rel="stylesheet">
# <!-- Fontawesome -->
# <link href="/vendor/fontawesome/css/font-awesome.css" rel="stylesheet">
# </link></link></link></link></link></link></link></link></link></link></link></link></link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-54HQHT" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Preloader -->
# <!-- MOBILE MENU -->
# <section id="idMobileMenuSection">
# <div class="ed-mob-menu" data-offset-top="33" data-spy="affix">
# <div class="ed-mob-menu-con">
# <div class="ed-mm-left">
# <div class="wed-logo">
# <a href="/">
0l0,9.73015c0,0.26551 0.07325,0.45293 0.22383,0.55835c0.18313,0.13666 0.60638,0.20694 1.2738,0.20694c0.64301,0 1.05811,-0.07028 1.25345,-0.20304l-0.00814,-0.0039z" fill="#d40e14" id="svg_1" stroke="null"></path> <path d="m2.10891,20.66925l10.3817,0c1.01741,0 1.78658,0.30846 2.08774,1.69458c0.33371,1.5423 0.19534,2.61605 -1.61158,2.73709l-3.2598,0.22256c2.39703,14.54055 16.42107,19.28068 24.05575,3.61952c1.26566,-2.59262 1.6767,-3.06507 3.06038,-2.73319c1.87611,0.44512 2.1325,1.3744 1.23718,3.98655c-6.60099,19.30801 -28.78877,21.24077 -33.1433,-4.54099l-2.64528,0.18351c-2.15692,0.14837 -2.23831,-1.59696 -2.23831,-2.56529c0,-1.91714 0.74068,-2.60434 2.07553,-2.60434z" fill="#d40e14" id="svg_2" stroke="null"></path> <path d="m43.70082,15.03107c0,2.04208 -1.72554,3.69761 -3.85397,3.69761s-3.85397,-1.65553 -3.85397,-3.69761c0,-2.04208 1.72554,-3.69761 3.85397,-3.69761s3.85397,1.65553 3.85397,3.69761z" fill="#d40e14" id="svg_3" stroke="null"></path> </svg>
# </a>
# </div>
# </div>
# <div class="ed-mm-right">
# <div class="ed-mm-menu">
# <a class="ed-micon" href="#"><i class="fa fa-bars"></i></a>
# <div class="ed-mm-inn tui-bck-blue60">
# <div class="text-right">
# <a class="ed-mi-close" href="#"><i class="fa fa-times"></i></a>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(6);">
#                                 Destinos
#                                         <img id="iconMobileMenu-6" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-6" style="display:none;">
# <ul>
# <li>
# <a class="destinationitem destinationitem1442" data-destid="1442" href="/buscador-destinos/europa" style="text-transform: none;">Europa</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1443" data-destid="1443" href="/buscador-destinos/africa" style="text-transform: none;">África</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1444" data-destid="1444" href="/buscador-destinos/asia" style="text-transform: none;">Asia</a>
# </li>
# <li>
# <a class="destinationitem destinationitem628" data-destid="628" href="/buscador-destinos/oriente-medio" style="text-transform: none;">Oriente Medio</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1447" data-destid="1447" href="/buscador-destinos/islas-exoticas" style="text-transform: none;">Islas Exóticas</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1445" data-destid="1445" href="/buscador-destinos/oceania" style="text-transform: none;">Oceanía</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1441" data-destid="1441" href="/buscador-destinos/america" style="text-transform: none;">América</a>
# </li>
# <li>
# <a class="destinationitem destinationitem114" data-destid="114" href="/buscador-destinos/caribe" style="text-transform: none;">Caribe</a>
# </li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(7);">
#                                 Catálogos
#                                         <img id="iconMobileMenu-7" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-7" style="display:none;">
# <ul>
# <li><a href="/catalogos" style="text-transform: none;">Catálogos</a></li>
# <li><a href="/Boletines-de-ofertas" style="text-transform: none;">Boletines de Ofertas</a></li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(8);">
#                                 Ofertas
#                                         <img id="iconMobileMenu-8" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-8" style="display:none;">
# <ul>
# <li><a href="/ofertas">Ofertas</a></li>
# <li><a href="/viajes?tag=rumbo-a-asia-oriental">Rumbo a Asia Oriental</a></li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="/viajes?tag=al-completo">
#                                     Al Completo
#                                 </a>
# </h4>
# <h4>
# <a class="mm-arr mr-2" href="/viajes?tag=a-tu-alcance">
#                                     A tu Alcance
#                                 </a>
# </h4>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(105);">
#                                 Salidas Garantizadas
#                                         <img id="iconMobileMenu-105" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-105" style="display:none;">
# <ul>
# <li><a href="/viajes?tag=cruceros-fluviales">Cruceros Fluviales</a></li>
# <li><a href="/viajes?tag=semana-santa">Semana Santa</a></li>
# <li><a href="/viajes?tag=puente-de-mayo">Puente de Mayo</a></li>
# <li><a href="/viajes?tag=salidas-garantizadas">Todas las Salidas Garantizadas</a></li>
# </ul> </div>
# <div class="mt-2">
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/quienes-somos-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/quienes-somos">Quiénes Somos</a>
# </h4>
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/contacto-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/contactanos">Contáctanos</a>
# </h4>
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/trabaja-con-nosotros-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/trabaja-con-nosotros">Trabaja con nosotros</a>
# </h4>
# <div>
# <a class="btn-tui-darkblue-login" data-target="#modalLogin" data-toggle="modal" href="#modalLogin" id="idBotonlogin" title="Login/Registro"> Acceso agencias</a>
# </div>
# <div class="mobile-social-media foot-social foot-com">
# <div>Síguenos en redes</div>
# <ul>
# <li><a href="https://www.facebook.com/tuispain" target="_blank"><span class="fa fa fa-facebook"></span></a> </li>
# <li><a href="https://www.instagram.com/tuispain/?hl=es" target="_blank"><span class="fa fa fa-instagram"></span></a> </li>
# <li><a href="https://es.linkedin.com/company/tuigroup" target="_blank"><span class="fa fa fa-linkedin"></span></a> </li>
# <li><a href="https://www.youtube.com/user/TuiSpain" target="_blank"><span class="fa fa fa-youtube"></span></a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></section>
# <style>
#     .rotated {
#         transform: rotate(180deg);
#         -ms-transform: rotate(180deg); /* IE 9 */
#         -moz-transform: rotate(180deg); /* Firefox */
#         -webkit-transform: rotate(180deg); /* Safari and Chrome */
#         -o-transform: rotate(180deg); /* Opera */
#     }
#
# </style>
# <script>
#
#     function mostrarCapaMenuMobile(itemId) {
#         $('#subMobileMenu-' + itemId).slideToggle();
#         if ($('#iconMobileMenu-' + itemId).hasClass("rotated")) {
#             $('#iconMobileMenu-' + itemId).removeClass("rotated");
#         } else {
#             $('#iconMobileMenu-' + itemId).addClass("rotated");
#         }
#     }
# </script>
# <!--HEADER SECTION-->
# <section id="idMenuSection">
# <!-- TOP BAR -->
# <!-- LOGO AND MENU SECTION -->
# <div class="top-logo" data-offset-top="33" data-spy="affix">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <div class="wed-logo">
# <a href="/">
# <svg class="main-nav__icon-tui / u-pos-abs" height="57" viewbox="0 5 70 45" width="120" xmlns="http://www.w3.org/2000/svg"> <path d="m79.57487,39.14251c0.07732,-0.06247 0.1343,-0.13275 0.17093,-0.21085s0.05291,-0.19523 0.05291,-0.34751l0,-11.4052c0,-0.15618 -0.01628,-0.27332 -0.05291,-0.35531s-0.0936,-0.14837 -0.17093,-0.20304c-0.18313,-0.13666 -0.59824,-0.20694 -1.25345,-0.20694c-0.66742,0 -1.09067,0.07028 -1.2738,0.20694c-0.07732,0.05466 -0.1343,0.12495 -0.17093,0.20304s-0.05291,0.19913 -0.05291,0.35531l0,11.4052c0,0.2538 0.07325,0.44121 0.22383,0.55835c0.18313,0.13666 0.60638,0.20694 1.2738,0.20694c0.65522,0 1.07032,-0.07028 1.25345,-0.20694zm-8.86779,0.06638c0.67963,-0.22256 1.23718,-0.53492 1.6767,-0.93319s0.75696,-0.86681 0.96044,-1.41345s0.30522,-1.13622 0.30522,-1.77657l0,-7.91062c0,-0.26551 -0.07325,-0.45293 -0.21569,-0.55835c-0.19534,-0.13666 -0.61045,-0.20694 -1.25345,-0.20694c-0.66742,0 -1.09067,0.07028 -1.2738,0.20694c-0.08546,0.05466 -0.14244,0.12495 -0.175,0.20304s-0.04884,0.19913 -0.04884,0.35531l0,7.87548c0,0.31236 -0.05698,0.62863 -0.17093,0.95662s-0.3622,0.5974 -0.74068,0.81215c-0.38255,0.21475 -0.88719,0.32017 -1.51391,0.32017c-0.43138,0 -0.80579,-0.05076 -1.11102,-0.14837s-0.55754,-0.24208 -0.75289,-0.4256c-0.19534,-0.18351 -0.33778,-0.40217 -0.42731,-0.65987s-0.1343,-0.54273 -0.1343,-0.85119l0,-7.87548c0,-0.26551 -0.07325,-0.45293 -0.21569,-0.55835c-0.19534,-0.13666 -0.61045,-0.20694 -1
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Jambo_box953cc55869b84f359624323d345adf16.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Safari Jambo
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/safari-jambo-opciones';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1444" data-destinationid="1444" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Asia</h4></div>
# <ul>
# <li><a href="/viajes/butan" style="text-transform: none;">Bután</a></li>
# <li><a href="/viajes/camboya" style="text-transform: none;">Camboya</a></li>
# <li><a href="/viajes/china" style="text-transform: none;">China</a></li>
# <li><a href="/viajes/corea-del-sur" style="text-transform: none;">Corea Del Sur</a></li>
# <li><a href="/viajes/filipinas" style="text-transform: none;">Filipinas</a></li>
# <li><a href="/viajes/india" style="text-transform: none;">India</a></li>
# <li><a href="/viajes/indonesia" style="text-transform: none;">Indonesia</a></li>
# <li><a href="/viajes/japon" style="text-transform: none;">Japón</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/laos" style="text-transform: none;">Laos</a></li>
# <li><a href="/viajes/malasia" style="text-transform: none;">Malasia</a></li>
# <li><a href="/viajes/mongolia" style="text-transform: none;">Mongolia</a></li>
# <li><a href="/viajes/nepal" style="text-transform: none;">Nepal</a></li>
# <li><a href="/viajes/singapur" style="text-transform: none;">Singapur</a></li>
# <li><a href="/viajes/sri-lanka" style="text-transform: none;">Sri Lanka</a></li>
# <li><a href="/viajes/tailandia" style="text-transform: none;">Tailandia</a></li>
# <li><a href="/viajes/taiwan" style="text-transform: none;">Taiwán</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/uzbekistán" style="text-transform: none;">Uzbekistán</a></li>
# <li><a href="/viajes/vietnam" style="text-transform: none;">Vietnam</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Thailand_phuket_top_view_aerial_beautiful_crystal_clear_box_70015144913b97ae916e64f4da3aa66a377ad401d.jpg"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Triángulo del Oro y Phuket - salida lunes
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/triangulo-del-oro-y-phuket-salida-lunes';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem628" data-destinationid="628" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Oriente Medio</h4></div>
# <ul>
# <li><a href="/viajes/emiratos-arabes-unidos" style="text-transform: none;">Emiratos Árabes Unidos</a></li>
# <li><a href="/viajes/georgia" style="text-transform: none;">Georgia</a></li>
# <li><a href="/viajes/jordania" style="text-transform: none;">Jordania</a></li>
# <li><a href="/viajes/oman" style="text-transform: none;">Omán</a></li>
# <li><a href="/viajes/qatar" style="text-transform: none;">Qatar</a></li>
# <li><a href="/viajes/turquía" style="text-transform: none;">Turquía</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Dubai_Maldivas_new_box6f9eab0d295b4db791c90d3b840ffd0153e57937a7f44b17a5a52cfabd2363af.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Dubái y Maldivas
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/dubai-y-maldivas';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1447" data-destinationid="1447" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Islas Exóticas</h4></div>
# <ul>
# <li><a href="/viajes/fiji" style="text-transform: none;">Fiji</a></li>
# <li><a href="/viajes/islas-cook" style="text-transform: none;">Islas Cook</a></li>
# <li><a href="/viajes/maldivas" style="text-transform: none;">Maldivas</a></li>
# <li><a href="/viajes/mauricio" style="text-transform: none;">Mauricio</a></li>
# <li><a href="/viajes/nueva-caledonia" style="text-transform: none;">Nueva Caledonia</a></li>
# <li><a href="/viajes/polinesia-francesa" style="text-transform: none;">Polinesia Francesa</a></li>
# <li><a href="/viajes/samoa" style="text-transform: none;">Samoa</a></li>
# <li><a href="/viajes/seychelles" style="text-transform: none;">Seychelles</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/zanzibar" style="text-transform: none;">Zanzíbar</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Dubai_Maldivas_new_box6f9eab0d295b4db791c90d3b840ffd0153e57937a7f44b17a5a52cfabd2363af.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Dubái y Maldivas
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/dubai-y-maldivas';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1445" data-destinationid="1445" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Oceanía</h4></div>
# <ul>
# <li><a href="/viajes/australia" style="text-transform: none;">Australia</a></li>
# <li><a href="/viajes/nueva-zelanda" style="text-transform: none;">Nueva Zelanda</a></li>
# <li><a href="/viajes/papuanuevaguinea" style="text-transform: none;">Papúa Nueva Guinea</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Diseño_sin_título_-_2022-02-23T151554.782d29038cf5ba242a4899c4beaeca12b36.jpg"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Australia en autocaravana - Ruta A
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/australia-en-autocaravana-ruta-a';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1441" data-destinationid="1441" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">América</h4></div>
# <li><a href="/viajes/curacao" style="text-transform: none;">Curaçao</a></li>
# <li><a href="/viajes/dominica" style="text-transform: none;">Dominica</a></li>
# <li><a href="/viajes/granadacaribe" style="text-transform: none;">Granada</a></li>
# <li><a href="/viajes/guadalupe" style="text-transform: none;">Guadalupe</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/islascaiman" style="text-transform: none;">Islas Caimán</a></li>
# <li><a href="/viajes/jamaica" style="text-transform: none;">Jamaica</a></li>
# <li><a href="/viajes/martinica" style="text-transform: none;">Martinica</a></li>
# <li><a href="/viajes/puerto-rico" style="text-transform: none;">Puerto Rico</a></li>
# <li><a href="/viajes/republica-dominicana" style="text-transform: none;">República Dominicana</a></li>
# <li><a href="/viajes/rivieramaya" style="text-transform: none;">Riviera Maya</a></li>
# <li><a href="/viajes/saint-martin" style="text-transform: none;">Saint Martin</a></li>
# <li><a href="/viajes/santa-lucia" style="text-transform: none;">Santa Lucía</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/turksandcaicos" style="text-transform: none;">Turks and Caicos</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Tesoros_de_México_-miniatura9812514644ad446e9f41ab81d9d733e8.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Tesoros de México
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/tesoros-de-mexico';">Ver producto</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </li>
# <li class="cour-menu" style="">
# <a class="mm-arr" href="/catalogos">Catálogos</a>
# <div class="mm-pos" style="left:inherit">
# <div class="cour-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/catalogos">Catálogos</a></li>
# <li><a href="/Boletines-de-ofertas">Boletines de Ofertas</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="ofer-menu" style="">
# <a class="mm-arr" href="/ofertas">Ofertas</a>
# <div class="mm-pos" style="left:inherit">
# <div class="ofer-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/ofertas">Ofertas</a></li>
# <li><a href="/viajes?tag=rumbo-a-asia-oriental">Rumbo a Asia Oriental</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="" style="">
# <a class="mm-arr" href="/viajes?tag=al-completo">Al Completo</a>
# </li>
# <li class="" style="">
# <a class="mm-arr" href="/viajes?tag=a-tu-alcance">A tu Alcance</a>
# </li>
# <li class="admi-menu" style="">
# <a class="mm-arr" href="/viajes?tag=salidas-garantizadas">Salidas Garantizadas</a>
# <div class="mm-pos" style="left:inherit">
# <div class="admi-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/viajes?tag=cruceros-fluviales">Cruceros Fluviales</a></li>
# <li><a href="/viajes?tag=semana-santa">Semana Santa</a></li>
# <li><a href="/viajes?tag=puente-de-mayo">Puente de Mayo</a></li>
# <li><a href="/viajes?tag=salidas-garantizadas">Todas las Salidas Garantizadas</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li id="openBtn2">
# </li>
# <div class="wed-login">
# <a class="btn-tui-darkblue-login" data-target="#modalLogin" data-toggle="modal" href="#modalLogin" id="idBotonlogin" title="Login/Registro"> Acceso agencias</a>
# </div>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--  Modal LOGIN-->
# <div aria-hidden="true" class="modal fade hmodal-info tui-darkblue" id="modalLogin" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-login">
# <div class="modal-personalizado modal-content">
# <div class="color-line"></div>
# <div class="modal-header" style="padding:5px;">
# <button aria-label="Close" class="close" data-dismiss="modal" style="margin:5px;" title="Cerrar" type="button"><span aria-hidden="true">x</span></button>
# <h4 class="modal-title" style="margin:10px;margin-bottom:-10px;"> ¡Bienvenido! </h4>
# <small class="font-bold" id="moTitle2" name="moTitle" style="padding-left:5px;" value=""></small>
# </div>
# <div class="modal-body col-md-12" id="login-form">
# <div class="col-md-6 border-right-only">
# <h4>Inicia sesión</h4>
# <form action="/Account/LogIn" id="frmLogin" method="post"> <form class="col s12" id="floating-login-form">
# <div class="row">
# <div class="input-field col s11">
# <input class="form-control brd-rd-0" id="username-login1" name="username" placeholder="Usuario" style="padding:4px;" type="text"/>
# </div>
# </div>
# <div class="row">
# <div class="input-field col s11">
# <input class="form-control brd-rd-0" id="password-login1" name="password" placeholder="Contraseña" style="padding:4px;" type="password"/>
# </div>
# </div>
# <div id="reCaptchaLogin1">
# <input id="g-recaptcha-responselogin1" name="g-recaptcha-response" type="hidden"/>
# </div>
# <div class="row">
# <div class="input-field col s11">
# <button class="btn-tui-blue" id="loginButton" onclick="handleLogin()" type="button" value="Accede">Accede</button>
# <br/>
# <a href="/Account/ForgotPassword/">¿Has olvidado la contraseña?</a>
# </div>
# </div>
# </form>
# </form>
# <script src="https://www.google.com/recaptcha/api.js?render=6LdpiM8UAAAAAM210zQdB7PwQtgnvC8iMxX7Qci6"></script>
# <script>
#                                 async function handleLogin() {
#                                     try {
#                                         const loginButton = document.getElementById('loginButton');
#                                         loginButton.disabled = true;
#                                         const token = await generateRecaptchaToken();
#                                         document.getElementById('g-recaptcha-responselogin1').value = token;
#                                         document.getElementById('frmLogin').submit();
#
#                                     } catch (error) {
#                                         loginButton.disabled = false;
#                                     }
#                                 }
#
#                                 function generateRecaptchaToken() {
#                                     return new Promise((resolve, reject) => {
#                                         grecaptcha.ready(() => {
#                                             grecaptcha.execute('6LdpiM8UAAAAAM210zQdB7PwQtgnvC8iMxX7Qci6', { action: 'login' })
#                                                 .then(token => resolve(token))
#                                                 .catch(error => reject(error));
#                                         });
#                                     });
#                                 }
#                             </script>
# </div>
# <div class="col-md-6">
# <h4>Registro</h4>
# <div class="col s11">
# <h5>¿Eres un nuevo agente?</h5>
# <p>Somos un turoperador dirigido a agencias de viajes. Si eres un nuevo agente regístrate aquí.</p>
# <div class="input-field col s4" style="">
# <a class="btn-tui-blue-link" href="/Account/Registro/" style="line-height:inherit;margin-top: 15px;">Regístrate</a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-footer" style="padding:7px;">
# </div>
# </div>
# </div>
# </div>
# <!--  Modal PRESUPUESTOS y Reservas-->
# <div aria-hidden="true" class="modal fade hmodal-info tui-darkblue" id="modalPresupuestos" role="dialog" style="border-radius:0px;" tabindex="-2">
# <div class="modal-dialog modal-login">
# <div class="modal-personalizado modal-content">
# <div class="color-line"></div>
# <div class="modal-header" style="padding:5px;">
# <button aria-label="Close" class="close" data-dismiss="modal" style="margin:5px;" title="Cerrar" type="button"><span aria-hidden="true">x</span></button>
# <h4 class="modal-title" style="margin:10px;margin-bottom:-10px;"> Busca tus prespuestos y reservas</h4>
# <small class="font-bold" id="moTitle2" name="moTitle" style="padding-left:5px;" value=""></small>
# </div>
# <div class="modal-body col-md-12">
# <div class="col-md-6 border-right-only" style="padding-bottom: 20px;">
# <h4>Presupuesto</h4>
# <div class="row col-md-12">
# <div class="input-field">
# ...
#         function marcaUbi(event, id) {
#             var idcheck = id
#             var checked = document.getElementById(event.target.id).checked;
#             if (checked) {
#                 ubics.push(id);
#             } else { //remove id lista
#                 for (var i = 0; i < ubics.length; i++) {
#                     if (ubics[i] === idcheck) {
#                         ubics.splice(i, 1);
#                     }
#                 }
#             }
#             //    console.log("---- ubicaciones marcados: ----");
#             //for (var i = 0; i < ubics.length; i++) {
#             //    console.log(ubics[i]);
#             //}
#             enviaFiltros();
#         }
#
#         function muestraLista() {
#             $(".lista").toggle(true);
#             $(".bloques").toggle(false);
#         }
#
#         function muestraBloques() {
#             $(".bloques").toggle(true);
#             $(".lista").toggle(false);
#         }
#     </script>
# <script cookie-consent="functionality">
#
#         function resetearRecaptcha() {
#             $.ajax({
#                 type: "GET",
#                 url: '/Account/LoginForm',
#                 success: function (response) {
#                 $('#reCaptchaLogin1').html(response);
#                 var compruebaRecaptcha = setInterval(function() {
#                 if ($('#g-recaptcha-response').val() != '' && $('#g-recaptcha-response').val() != undefined) {
#                 clearInterval(compruebaRecaptcha);
#                 $('#recaptcha').removeAttr("disabled");
#                 }
#                 }, 1000);
#                 },
#                 error: function (result) {
#                 $('#reCaptchaLogin1').html('');
#                 }
#             });
#         }
#
#
#         $(function () {
#
#             if ($("#idcheckmantenimiento").val() == "Mantenimiento") {
#                 $("#idBotonlogin").click();
#             }
#
#
#             //$("#select-search").autocomplete({
#             //        source: "/Ajax/Search"
#             //    });
#
#             //ControlCookies();
#             //$('#btn-search').click(function () {
#             //    var gw2 = documente.getElementById('select-search');
#             //});
# //$("#select-search").autocomplete({
# //    source: function (request, response) {
# //        $.ajax({
# //            url: "/Home/Search", type: "POST", dataType: "json",
# //            //original code
# //            //data: { searchText: request.id, maxResults: 10 },
# //            //updated code; updated to request.term
# //            //and removed the maxResults since you are not using it on the server side
# //            data: { srch: request.term },
#
# //            success: function (data) {
# //                response($.map(data, function (item) {
# //                    //original code
# //                    //return { label: item.FullName, value: item.FullName, id: item.TagId };
# //                    //updated code
# //                    return { label: item.label, value: item.label, id: item.id };
# //                }));
# //            },
# //        select: function (event, ui) {
# //                //update the jQuery selector here to your target hidden field
# //            $("input[type=hidden]").val(ui.item.id);
# //        }
# //        });
# //    },
# //});
#
#             //var availableTags = ["ActionScript", "AppleScript", "Asp", "BASIC", "C", "C++", "Clojure", "COBOL", "ColdFusion", "Erlang", "Fortran", "Groovy", "Haskell", "Java", "JavaScript", "Lisp", "Perl", "PHP", "Python", "Ruby", "Scala", "Scheme"];
#             //$("#select-search").autocomplete({ source: availableTags });
#             //$("#select-search").on("keyup", function () {
#             //    var term = $(this).val();
#             //    $(this).autocomplete("destroy");
#             //    console.log(term);
#             //    $(this).autocomplete({ source: availableTags });
#
#             //});
#             //var miResponse;
#
#             $("#select-search").autocomplete({
#                 source: function (request, response) {
#                     //console.log(request);
#                     console.log(response);
#                     $.ajax( {
#                       url: "/Home/Search",
#                       dataType: "json",
#                       type: "POST",
#                       data: {
#                         term: request.term
#                       },
#                         success: function (data) {
#                             //alert(data);
#                             console.log(data);
#                             response( data );
#                         },
#                         error: function (err) {
#                             //alert("error");
#                             console.log(err);
#                         }
#                     });
#                   },
#                     minLength: 2
#             });
#
#            $('#modalpres').click(function () {
#                     bootbox.dialog({
#                             title: 'Por favor, introduzca el localizador del presupuesto:',
#                             message: "<input type='text' id='inputLocalicer' class='form-control' placeholder='XAAA1A1-00' /> </br> <p style='font-size:16px;'>O accede al <a href='/Agency/ListBookings'> <b>listado de reservas</b>.</a></p>",
#                             buttons: {
#                                 ok: {
#                                     label: "Enviar",
#                                     className: 'btn-info',
#                                     callback: function (item) {
#                                         var xd = document.getElementById('inputLocalicer');
#                                         var token = '';//document.getElementById('usuToken').value;
#                                         var link = 'https://reservas-online.es.tui.com/b2b/redirectionDeepLinkQuote.jsf?quoteReference=' + xd.value + '&UP=' + token;
#                                         if (xd.value)
#                                             window.location.href = link;  //redirige
#                                             //window.location.replace(link); //otra pestaña
#                                     }
#                                 }
#                             }
#                         });
#            });
#
#
#         });
#
#
#          function goToBooking() {
#              var loc = document.getElementById("idLoc").value;
#              if (loc) {
#                  document.getElementById("buscaReserva").href = "/Agency/BookingDetail/" + loc;
#                  document.getElementById("buscaReserva").click();
#              }
#              //else if (loc2) {
#              //    var link = "/Agency/BookingDetail?id=" + loc2;
#              //    window.open(link, "_self");
#              //}
#             //$.ajax({
#             //    type: "POST",
#             //    url: urlGetLocs + "?id="+loc,
#             //    success: function(msg) {
#             //    }
#             //});
#         }
#
#
#          function buscaViajeFreetext() {
#             var loc = document.getElementById("idBuscViajeDash").value;
#
#              console.log(loc);
#              if (loc) {
#                  var link = "/viajes?freeText=" + loc;
#                  window.open(link,"_self");
#              }
#              //else {
#              //    swal({ "Por favor, introduzca algún destino"});
#              //}
#
#             //$.ajax({
#             //    type: "POST",
#             //    url: urlGetLocs + "?id="+loc,
#             //    success: function(msg) {
#             //    }
#             //});
#         }
#
#
#     function goToQuotation() {
#         debugger;
#         var presu1 = document.getElementById('inputPresupuesto');
#             var presu2 = document.getElementById('inputPresupuestoDash');
#             var quotationId = "";
#             if (presu1.value || presu2.value) {
#                 if (presu1.value) {
#                     quotationId = presu1.value;
#                 } else if (presu2.value) {
#                     quotationId = presu2.value;
#                 }
#                 var link = "/Agency/QuoteInfo" + "?quotationId=" + quotationId;
#                 window.open(link, "_blank");
#             }
#     }
#
#         function chekKey(e) {
#             //See notes about 'which' and 'key'
#             if (e.keyCode == 13) { //si presiona enter
#                 goToBooking();
#             }
#         }
#         function chekKeyPresu(e) {
#             //See notes about 'which' and 'key'
#             if (e.keyCode == 13) { //si presiona enter
#                 goToQuotation();
#             }
#         }
#
#         function cambiaImgTV(element) {
#             var tipovviaje_back = element.id;
#             var default_img = "/images/demo/tipos-viaje.jpg";
#             if (tipovviaje_back) {
#                 $('#img_tipoViaje').attr('src', tipovviaje_back);
#                 //document.getElementById('img_tipoViaje').src == tipovviaje_back;
#                 //console.log(document.getElementById('img_tipoViaje').src);
#             }
#             //else {
#             //    document.getElementById('img_tipoViaje').src = default_img;
#             //}
#         }
#
#         //Modal contáctanos inicio
#         $("#btnClose").click(function () {
#             $("#modalContacto").hide();
#         });
#         function cambiarTexto() {
#             $("#labelUno").html("<a class='labelContacto linkContacto' href='mailto:info.ts@tui.com'>info.ts@tui.com</a>");
#             $("#labelDos").html("<a class='labelContacto linkContacto' href='tel://+34917582828'>+34 91 758 2828</a>");
#         }
#
#         //$(".b_packages").click(function () {   //Angel 15/04/2020 - Lo comento por que está haciendo que fallen todos los enlaces con target = "_blank" de la web"
#         //    var location = $(this).find("a").attr("href");
#
#         //    if (location != undefined && location != null) {
#         //        window.location = location;
#         //    }
#
#         //    return false;
#         //});
#
#         ///////////////////////////// COOKIES  (ANTIGUO)//////////////////////////////
#         //function ControlCookies() {
#         //    if (localStorage.controlcookie > 0) {
#         //        console.log(localStorage.controlcookie);
#         //        $('#modalCookies').hide();
#         //    } else
#         //         $('#modalCookies').show();
#
#         //}
#         //function aceptaCookies() {
#         //    // si variable no existe se crea (al clicar en Aceptar)
#         //    localStorage.controlcookie = (localStorage.controlcookie || 0);
#         //    // incrementamos cuenta de la cookie
#         //    localStorage.controlcookie++;
#         //    //cierro mensaje
#         //      $('#modalCookies').hide();
#         //    console.log("El usuario aceptó las cookies");
#         //}
#         //function CancelarCookies() {  //por el momento no lo estamos usando
# 	       // console.log("rrr")
#         //    cookies.style.display = 'none';
#         //}
#
#         //-----
#          //var settings = {
#          //       message: 'Esta web utiliza cookies para mejorar la experiencia y proporcionar funcionalidades adicionales.. <b> ás información ',
#          //       moreLinkLabel: 'aquí.</b>',
#          //       messageMaxHeightPercent: 30,
#          //       moreLink: '/Content/View/politica-privacidad/',
#          //       delay: 1000,
#          //       allowAdvancedOptions: true,
#          //       OnAccept: function () {
#          //           console.log('Yay! User accepted your cookies window!');
#          //           console.log('User preferences');
#          //           var preferences = $.fn.bsgdprcookies.GetUserPreferences();
#          //           console.log(preferences);
#
#          //       }
#          //   }
#
#          //   $(document).ready(function () {
#          //       $('body').bsgdprcookies(settings);
#          //       $("#modalCookies").on("show", function () {
#          //       $('#cookiesBtn').on('click', function () {
#          //           $('body').bsgdprcookies(settings, 'reinit');
#          //       });
#          //   });
#
#
#         /////////////////////////////////////////////////////////////////////////////
#
# </script>
# <style>
#
#         .grecaptcha-badge {
#             display: none !important;
#         }
#
#         .carousel-control {
#             width: 4%;
#         }
#
#             .carousel-control.left, .carousel-control.right {
#                 margin-left: 15px;
#                 background-image: none;
#             }
#
#         @media (max-width: 475px) {
#             .degradado {
#                 padding-top: 25%;
#             }
#         }
#
#         @media (min-width: 475px) and (max-width: 767px ) {
#             .degradado {
#                 padding-top: 50%;
#             }
#         }
#
#         @media (max-width: 767px) { /*Mobile*/
#             .carousel-inner .active.left {
#                 left: -100%;
#             }
#
#             .carousel-inner .next {
#                 left: 100%;
#             }
#
#             .carousel-inner .prev {
#                 left: -100%;
#             }
#
#             .active > div {
#                 /*display: none;*/
#             }
#
#                 .active > div:first-child {
#                     display: block;
#                 }
#
#             .search-view-mobile {
#                 display: initial;
#             }
#
#             .search-view-web {
#                 display: none;
#             }
#
#             .filter-view-mobile {
#                 display: initial;
#             }
#
#             .filter-view-web {
#                 display: none;
#             }
#             /*//modal cookies*/
#             .cc_dialog.interstitial {
#                 right: 5vw;
#                 top: 5vh;
#                 left: 5vw;
#                 max-width: 90%;
#                 position: fixed;
#                 max-height: 90%;
#                 overflow: auto;
#             }
#
#             .lista-flotante {
#                 display: none;
#             }
#             /*.mobile-scrollable {
#                 display: block;
#                 overflow-x: auto;
#             }*/
#         }
#
#         @media (min-width: 767px) and (max-width: 992px ) {
#             .carousel-inner .active.left {
#                 left: -50%;
#             }
#
#             .carousel-inner .next {
#                 left: 50%;
#             }
#
#             .carousel-inner .prev {
#                 left: -50%;
#             }
#
#             .active > div {
#                 /*display: none;*/
#             }
#
#                 .active > div:first-child {
#                     display: block;
#                 }
#
#                     .active > div:first-child + div {
#                         display: block;
#                     }
#
#             .search-view-mobile {
#                 display: initial;
#             }
#
#             .search-view-web {
#                 display: none;
#             }
#
#             .filter-view-mobile {
#                 display: initial;
#             }
#
#             .filter-view-web {
#                 display: none;
#             }
#
#             .degradado {
#                 padding-top: 0%;
#             }
#
#             .lista-flotante {
#                 display: block;
#             }
#         }
#
#         @media (min-width: 992px ) {
#             .carousel-inner .active.left {
#                 left: -25%;
#             }
#
#             .carousel-inner .next {
#                 left: 25%;
#             }
#
#             .carousel-inner .prev {
#                 left: -25%;
#             }
#
#             .filter-view-mobile {
#                 display: none;
#             }
#
#             .filter-view-web {
#                 display: block;
#             }
#         }
#
#         /*@media print
#         {
#             .no-print, .no-print *
#             {
#                 display: none !important;
#             }
#         }*/
#
#         .swal-wide-auto {
#             width: auto !important;
#         }
#
#         .swal-tui-blue {
#             padding: 2%;
#             background-color: #70cbf4 !important;
#             color: white;
#             font-family: 'TUITypeLt', sans-serif !important;
#             font-size: 18px !important;
#             text-align: justify;
#             width: 32%;
#         }
#
#         /*.mobile-scrollable {
#                 display: block;
#                 overflow-x: auto;
#             }*/
#
#     </style>
# </link></link></body>
# </html>

# %%
#Vamos a extraer todas los contenidos de la clase landing-destination-title
clase_landing_destination_title=sopa_destinos.find_all("div", {"class":"landing-destination-title"})
print(len(clase_landing_destination_title))
# Out:
# 119

# %%
#Planteo el diccionario con lo que quiero extraer:
dictio_scrap_0 = {"nombre_pais": [],
                            "num_viajes_ofertados":[]}

# %%
def destinos_totales():
    for destino in clase_landing_destination_title:
        nombre_pais=" ".join(destino.get_text().split(" ")[:-1])
        #print(nombre_pais)
        num_viajes_ofertados=int(destino.get_text().split(" ")[-1:][0].strip("(").strip(")"))
        #print(num_viajes_ofertados)
        dictio_scrap_0["nombre_pais"].append(nombre_pais)
        dictio_scrap_0["num_viajes_ofertados"].append(num_viajes_ofertados)
    return dictio_scrap_0

# %%
for pais in dictio_scrap_0["nombre_pais"]:
    print(pais)
    URL_ESCRAPEO_VIAJES_PAIS=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","-") #url original
    print(URL_ESCRAPEO_VIAJES_PAIS)
    if "é" in pais.lower() or "á" in pais.lower() or "í" in pais.lower() or "ó" in pais.lower() or "ú" in pais.lower():
        URL_ESCRAPEO_VIAJES_PAIS_SIN_TILDE=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","-").replace("á","a").replace("Á","a").replace("é","e").replace("É","e").replace("í","i").replace("Í","i").replace("ó","o").replace("Ó","o").replace("ú","u").replace("Ú","u")
        print(URL_ESCRAPEO_VIAJES_PAIS_SIN_TILDE)

# %%
def crear_sopa(url):
    res_pais=rq.get(url)# Accedemos a la url
    if res_pais.status_code ==200:
        sopa_pais=bs(res_pais.content,"html.parser") # Creamos la sopa
    return sopa_pais

# %%
url_argentina = "https://es.tui.com/viajes/Argentina"
# Accedemos a la url
res_argentina=rq.get(url_argentina)
# Comprobamos que tenemos una respuesta correcta
res_argentina.status_code
# Creamos la sopa
sopa_argentina=bs(res_argentina.content,"html.parser")
sopa_argentina
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Consent Mode de Google, permite hacer un tracking de visitantes activos aunque no acepten las cookies -->
# <!-- Cookie Consent by https://www.FreePrivacyPolicy.com -->
# <script src="/vendor/cookieConsent/cookie-consent.js"></script>
# <script type="text/javascript">
#         document.addEventListener('DOMContentLoaded', function () {
#             cookieconsent.run({ "notice_banner_type": "interstitial", "consent_type": "express", "palette": "light", "language": "es", "website_name": "TUI", "cookies_policy_url": "https://es.tui.com/politica-privacidad" });
#         });
#     </script>
# <!-- End Cookie Consent -->
# <!-- Google Tag Manager -->
# <script cookie-consent="tracking" type="text/plain">
#         (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-54HQHT');
#
#         function prepairQuotation() {
#         console.log(item);
#         console.log(token);
#         var token = '';
#         var link = 'https://reservas-online.es.tui.com/b2b/redirectionDeepLinkQuote.jsf?quoteReference=' + xd.value + '&UP=' + token;
#         document.getElementById('btnEnvio').href = link;
#         }
#     </script>
# <!-- Page hiding snippet (recommended) -->
# <style>
#         .async-hide {
#             /*opacity: 0 !important*/
#         }
#
#         /*.ui-autocomplete-loading {
#             background: url(images/load-loading.gif) no-repeat left center #fff !important;
#             background-size: 40% !important;
#             background-position-x: -72px !important;
#         }*/
#     </style>
# <script cookie-consent="tracking" type="text/plain">
#         (function (a, s, y, n, c, h, i, d, e) {
#         s.className += ' ' + y;
#         h.end = i = function () { s.className = s.className.replace(RegExp(' ?' + y), '') };
#         (a[n] = a[n] || []).hide = h; setTimeout(function () { i(); h.end = null }, c);
#         })(window, document.documentElement, 'async-hide', 'dataLayer', 4000, { 'GTM-54HQHT': true });
#     </script>
# <!-- End Google Tag Manager -->
# <script>
#         var hideMenuSpecialDepartures = false;
#         var hideMenuTrìpTypes = false;
#     </script>
# <script cookie-consent="functionality" src="https://cdn.jsdelivr.net/npm/sweetalert2@9"></script>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="true" name="HandheldFriendly"/>
# <title>América-Argentina</title>
# <!-- FAV ICON -->
# <link href="/images/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/images/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/images/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/images/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/images/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/images/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/images/favicon/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/images/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- FONT-AWESOME ICON CSS -->
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <!--== ALL CSS FILES ==-->
# <link href="/css/jquery-ui.min.css" rel="stylesheet">
# <link href="/css/style.css?v=1.78.8.020250408170727" rel="stylesheet"/>
# <link href="/css/hero.css?v=1.78.8.020250408170727" rel="stylesheet"/>
# <link href="/css/materialize.css" rel="stylesheet"/><!-- NO tocar ni cambiar de versión, se van a la mierda el diseño-->
# <!-- v2-->
# <link href="/vendor/bootstrap/dist/css/bootstrap.css" rel="stylesheet"> <!-- v3.3.7-->
# <link href="/css/mob.css" rel="stylesheet"/>
# <link href="/css/animate.css" rel="stylesheet"/>
# <link href="/css/iconos-tui.css" rel="stylesheet"/>
# <link href="/vendor/metisMenu/dist/metisMenu.css" rel="stylesheet">
# <link href="/vendor/select2-3.5.2/select2b.css" rel="stylesheet">
# <!-- ==DATATABLES ==-->
# <link href="/vendor/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet">
# <link href="/vendor/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet">
# <link href="/vendor/datatables.net-buttons-bs/css/buttons.bootstrap.min.css" rel="stylesheet">
# <!-- Datetimepicker -->
# <link href="/js/bootstrap-datetimepicker-master/bootstrap-datetimepicker.css" rel="stylesheet">
# <!-- Datepicker -->
# <link href="/js/bootstrap-datepicker-1.9.0-dist/css/bootstrap-datepicker.css" rel="stylesheet">
# <!-- NanoScroller -->
# <link href="/vendor/nanoscroller/css/nanoscroller.min.css" rel="stylesheet">
# <!-- Slick -->
# <link href="/vendor/slick/slick.css" rel="stylesheet">
# <!-- FancyBox -->
# <link href="/vendor/fancybox/jquery.fancybox.css" rel="stylesheet">
# <!-- Fontawesome -->
# <link href="/vendor/fontawesome/css/font-awesome.css" rel="stylesheet">
# </link></link></link></link></link></link></link></link></link></link></link></link></link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-54HQHT" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Preloader -->
# <!-- MOBILE MENU -->
# <section id="idMobileMenuSection">
# <div class="ed-mob-menu" data-offset-top="33" data-spy="affix">
# <div class="ed-mob-menu-con">
# <div class="ed-mm-left">
# <div class="wed-logo">
# <a href="/">
# <svg class="main-nav__icon-tui / u-pos-abs" height="57" width="80" xmlns="http://www.w3.org/2000/svg"> <path d="m79.57487,39.14251c0.07732,-0.06247 0.1343,-0.13275 0.17093,-0.21085s0.05291,-0.19523 0.05291,-0.34751l0,-11.4052c0,-0.15618 -0.01628,-0.27332 -0.05291,-0.35531s-0.0936,-0.14837 -0.17093,-0.20304c-0.18313,-0.13666 -0.59824,-0.20694 -1.25345,-0.20694c-0.66742,0 -1.09067,0.07028 -1.2738,0.20694c-0.07732,0.05466 -0.1343,0.12495 -0.17093,0.20304s-0.05291,0.19913 -0.05291,0.35531l0,11.4052c0,0.2538 0.07325,0.44121 0.22383,0.55835c0.18313,0.13666 0.60638,0.20694 1.2738,0.20694c0.65522,0 1.07032,-0.07028 1.25345,-0.20694zm-8.86779,0.06638c0.67963,-0.22256 1.23718,-0.53492 1.6767,-0.93319s0.75696,-0.86681 0.96044,-1.41345s0.30522,-1.13622 0.30522,-1.77657l0,-7.91062c0,-0.26551 -0.07325,-0.45293 -0.21569,-0.55835c-0.19534,-0.13666 -0.61045,-0.20694 -1.25345,-0.20694c-0.66742,0 -1.09067,0.07028 -1.2738,0.20694c-0.08546,0.05466 -0.14244,0.12495 -0.175,0.20304s-0.04884,0.19913 -0.04884,0.35531l0,7.87548c0,0.31236 -0.05698,0.62863 -0.17093,0.95662s-0.3622,0.5974 -0.74068,0.81215c-0.38255,0.21475 -0.88719,0.32017 -1.51391,0.32017c-0.43138,0
# </div>
# <div class="ed-mm-right">
# <div class="ed-mm-menu">
# <a class="ed-micon" href="#"><i class="fa fa-bars"></i></a>
# <div class="ed-mm-inn tui-bck-blue60">
# <div class="text-right">
# <a class="ed-mi-close" href="#"><i class="fa fa-times"></i></a>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(6);">
#                                 Destinos
#                                         <img id="iconMobileMenu-6" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-6" style="display:none;">
# <ul>
# <li>
# <a class="destinationitem destinationitem1442" data-destid="1442" href="/buscador-destinos/europa" style="text-transform: none;">Europa</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1443" data-destid="1443" href="/buscador-destinos/africa" style="text-transform: none;">África</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1444" data-destid="1444" href="/buscador-destinos/asia" style="text-transform: none;">Asia</a>
# </li>
# <li>
# <a class="destinationitem destinationitem628" data-destid="628" href="/buscador-destinos/oriente-medio" style="text-transform: none;">Oriente Medio</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1447" data-destid="1447" href="/buscador-destinos/islas-exoticas" style="text-transform: none;">Islas Exóticas</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1445" data-destid="1445" href="/buscador-destinos/oceania" style="text-transform: none;">Oceanía</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1441" data-destid="1441" href="/buscador-destinos/america" style="text-transform: none;">América</a>
# </li>
# <li>
# <a class="destinationitem destinationitem114" data-destid="114" href="/buscador-destinos/caribe" style="text-transform: none;">Caribe</a>
# </li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(7);">
#                                 Catálogos
#                                         <img id="iconMobileMenu-7" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-7" style="display:none;">
# <ul>
# <li><a href="/catalogos" style="text-transform: none;">Catálogos</a></li>
# <li><a href="/Boletines-de-ofertas" style="text-transform: none;">Boletines de Ofertas</a></li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(8);">
#                                 Ofertas
#                                         <img id="iconMobileMenu-8" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-8" style="display:none;">
# <ul>
# <li><a href="/ofertas">Ofertas</a></li>
# <li><a href="/viajes?tag=rumbo-a-asia-oriental">Rumbo a Asia Oriental</a></li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="/viajes?tag=al-completo">
#                                     Al Completo
#                                 </a>
# </h4>
# <h4>
# <a class="mm-arr mr-2" href="/viajes?tag=a-tu-alcance">
#                                     A tu Alcance
#                                 </a>
# </h4>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(105);">
#                                 Salidas Garantizadas
#                                         <img id="iconMobileMenu-105" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-105" style="display:none;">
# <ul>
# <li><a href="/viajes?tag=cruceros-fluviales">Cruceros Fluviales</a></li>
# <li><a href="/viajes?tag=semana-santa">Semana Santa</a></li>
# <li><a href="/viajes?tag=puente-de-mayo">Puente de Mayo</a></li>
# <li><a href="/viajes?tag=salidas-garantizadas">Todas las Salidas Garantizadas</a></li>
# </ul> </div>
# <div class="mt-2">
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/quienes-somos-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/quienes-somos">Quiénes Somos</a>
# </h4>
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/contacto-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/contactanos">Contáctanos</a>
# </h4>
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/trabaja-con-nosotros-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/trabaja-con-nosotros">Trabaja con nosotros</a>
# </h4>
# <div>
# <a class="btn-tui-darkblue-login" data-target="#modalLogin" data-toggle="modal" href="#modalLogin" id="idBotonlogin" title="Login/Registro"> Acceso agencias</a>
# </div>
# <div class="mobile-social-media foot-social foot-com">
# <div>Síguenos en redes</div>
# <ul>
# <li><a href="https://www.facebook.com/tuispain" target="_blank"><span class="fa fa fa-facebook"></span></a> </li>
# <li><a href="https://www.instagram.com/tuispain/?hl=es" target="_blank"><span class="fa fa fa-instagram"></span></a> </li>
# <li><a href="https://es.linkedin.com/company/tuigroup" target="_blank"><span class="fa fa fa-linkedin"></span></a> </li>
# <li><a href="https://www.youtube.com/user/TuiSpain" target="_blank"><span class="fa fa fa-youtube"></span></a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></section>
# <style>
#     .rotated {
#         transform: rotate(180deg);
#         -ms-transform: rotate(180deg); /* IE 9 */
#         -moz-transform: rotate(180deg); /* Firefox */
#         -webkit-transform: rotate(180deg); /* Safari and Chrome */
#         -o-transform: rotate(180deg); /* Opera */
#     }
#
# </style>
# <script>
#
#     function mostrarCapaMenuMobile(itemId) {
#         $('#subMobileMenu-' + itemId).slideToggle();
#         if ($('#iconMobileMenu-' + itemId).hasClass("rotated")) {
#             $('#iconMobileMenu-' + itemId).removeClass("rotated");
#         } else {
#             $('#iconMobileMenu-' + itemId).addClass("rotated");
#         }
#     }
# </script>
# <!--HEADER SECTION-->
# <section id="idMenuSection">
# <!-- TOP BAR -->
# <!-- LOGO AND MENU SECTION -->
# <div class="top-logo" data-offset-top="33" data-spy="affix">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <div class="wed-logo">
# <a href="/">
#                         Grecia Clásica
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/grecia-clasica';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1443" data-destinationid="1443" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">África</h4></div>
# <ul>
# <li><a href="/viajes/botsuana" style="text-transform: none;">Botsuana</a></li>
# <li><a href="/viajes/cabo-verde" style="text-transform: none;">Cabo Verde</a></li>
# <li><a href="/viajes/egipto" style="text-transform: none;">Egipto</a></li>
# <li><a href="/viajes/kenia" style="text-transform: none;">Kenia</a></li>
# <li><a href="/viajes/madagascar" style="text-transform: none;">Madagascar</a></li>
# <li><a href="/viajes/marruecos" style="text-transform: none;">Marruecos</a></li>
# <li><a href="/viajes/namibia" style="text-transform: none;">Namibia</a></li>
# <li><a href="/viajes/reunion" style="text-transform: none;">Reunión</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/ruanda" style="text-transform: none;">Ruanda</a></li>
# <li><a href="/viajes/sudafrica" style="text-transform: none;">Sudáfrica</a></li>
# <li><a href="/viajes/tanzania" style="text-transform: none;">Tanzania</a></li>
# <li><a href="/viajes/tunez" style="text-transform: none;">Túnez</a></li>
# <li><a href="/viajes/uganda" style="text-transform: none;">Uganda</a></li>
# <li><a href="/viajes/zimbabue" style="text-transform: none;">Zimbabue</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Jambo_box953cc55869b84f359624323d345adf16.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Safari Jambo
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/safari-jambo-opciones';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1444" data-destinationid="1444" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Asia</h4></div>
# <ul>
# <li><a href="/viajes/butan" style="text-transform: none;">Bután</a></li>
# <li><a href="/viajes/camboya" style="text-transform: none;">Camboya</a></li>
# <li><a href="/viajes/china" style="text-transform: none;">China</a></li>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Dubai_Maldivas_new_box6f9eab0d295b4db791c90d3b840ffd0153e57937a7f44b17a5a52cfabd2363af.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Dubái y Maldivas
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/dubai-y-maldivas';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1447" data-destinationid="1447" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Islas Exóticas</h4></div>
# <ul>
# <li><a href="/viajes/fiji" style="text-transform: none;">Fiji</a></li>
# <li><a href="/viajes/islas-cook" style="text-transform: none;">Islas Cook</a></li>
# <li><a href="/viajes/maldivas" style="text-transform: none;">Maldivas</a></li>
# <li><a href="/viajes/mauricio" style="text-transform: none;">Mauricio</a></li>
# <li><a href="/viajes/nueva-caledonia" style="text-transform: none;">Nueva Caledonia</a></li>
# <li><a href="/viajes/polinesia-francesa" style="text-transform: none;">Polinesia Francesa</a></li>
# <li><a href="/viajes/samoa" style="text-transform: none;">Samoa</a></li>
# <li><a href="/viajes/seychelles" style="text-transform: none;">Seychelles</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/zanzibar" style="text-transform: none;">Zanzíbar</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Dubai_Maldivas_new_box6f9eab0d295b4db791c90d3b840ffd0153e57937a7f44b17a5a52cfabd2363af.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Dubái y Maldivas
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/dubai-y-maldivas';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1445" data-destinationid="1445" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Oceanía</h4></div>
# <ul>
# <li><a href="/viajes/australia" style="text-transform: none;">Australia</a></li>
# <li><a href="/viajes/nueva-zelanda" style="text-transform: none;">Nueva Zelanda</a></li>
# <li><a href="/viajes/papuanuevaguinea" style="text-transform: none;">Papúa Nueva Guinea</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Diseño_sin_título_-_2022-02-23T151554.782d29038cf5ba242a4899c4beaeca12b36.jpg"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Australia en autocaravana - Ruta A
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/australia-en-autocaravana-ruta-a';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1441" data-destinationid="1441" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">América</h4></div>
# <ul>
# <li><a href="/viajes/argentina" style="text-transform: none;">Argentina</a></li>
# <li><a href="/viajes/belice" style="text-transform: none;">Belice</a></li>
# <li><a href="/viajes/bolivia" style="text-transform: none;">Bolivia</a></li>
# <li><a href="/viajes/brasil" style="text-transform: none;">Brasil</a></li>
# <li><a href="/viajes/canada" style="text-transform: none;">Canadá</a></li>
# <li><a href="/viajes/chile" style="text-transform: none;">Chile</a></li>
# <li><a href="/viajes/colombia" style="text-transform: none;">Colombia</a></li>
# <li><a href="/viajes/costa-rica" style="text-transform: none;">Costa Rica</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/ecuador" style="text-transform: none;">Ecuador</a></li>
# <li><a href="/viajes/elsalvador" style="text-transform: none;">El Salvador</a></li>
# <li><a href="/viajes/estados-unidos" style="text-transform: none;">Estados Unidos</a></li>
# <li><a href="/viajes/guatemala" style="text-transform: none;">Guatemala</a></li>
# <li><a href="/viajes/honduras" style="text-transform: none;">Honduras</a></li>
# <li><a href="/viajes/mexico" style="text-transform: none;">México</a></li>
# <div style=""></div>
# <ul>
# <li><a href="/viajes/turksandcaicos" style="text-transform: none;">Turks and Caicos</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Tesoros_de_México_-miniatura9812514644ad446e9f41ab81d9d733e8.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Tesoros de México
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/tesoros-de-mexico';">Ver producto</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </li>
# <li class="cour-menu" style="">
# <a class="mm-arr" href="/catalogos">Catálogos</a>
# <div class="mm-pos" style="left:inherit">
# <div class="cour-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/catalogos">Catálogos</a></li>
# <li><a href="/Boletines-de-ofertas">Boletines de Ofertas</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="ofer-menu" style="">
# <a class="mm-arr" href="/ofertas">Ofertas</a>
# <div class="mm-pos" style="left:inherit">
# <div class="ofer-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/ofertas">Ofertas</a></li>
# <li><a href="/viajes?tag=rumbo-a-asia-oriental">Rumbo a Asia Oriental</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="" style="">
# <a class="mm-arr" href="/viajes?tag=al-completo">Al Completo</a>
# </li>
# <li class="" style="">
# <a class="mm-arr" href="/viajes?tag=a-tu-alcance">A tu Alcance</a>
# </li>
# <li class="admi-menu" style="">
# <a class="mm-arr" href="/viajes?tag=salidas-garantizadas">Salidas Garantizadas</a>
# <div class="mm-pos" style="left:inherit">
# <div class="admi-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/viajes?tag=cruceros-fluviales">Cruceros Fluviales</a></li>
# <li><a href="/viajes?tag=semana-santa">Semana Santa</a></li>
# <li><a href="/viajes?tag=puente-de-mayo">Puente de Mayo</a></li>
# <li><a href="/viajes?tag=salidas-garantizadas">Todas las Salidas Garantizadas</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li id="openBtn2">
# </li>
# <div class="wed-login">
# <a class="btn-tui-darkblue-login" data-target="#modalLogin" data-toggle="modal" href="#modalLogin" id="idBotonlogin" title="Login/Registro"> Acceso agencias</a>
# </div>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--  Modal LOGIN-->
# <div aria-hidden="true" class="modal fade hmodal-info tui-darkblue" id="modalLogin" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-login">
# <div class="modal-personalizado modal-content">
# <div class="color-line"></div>
# <div class="modal-header" style="padding:5px;">
# <button aria-label="Close" class="close" data-dismiss="modal" style="margin:5px;" title="Cerrar" type="button"><span aria-hidden="true">x</span></button>
# <h4 class="modal-title" style="margin:10px;margin-bottom:-10px;"> ¡Bienvenido! </h4>
# <small class="font-bold" id="moTitle2" name="moTitle" style="padding-left:5px;" value=""></small>
# </div>
# <div class="modal-body col-md-12" id="login-form">
# <div class="col-md-6 border-right-only">
# <h4>Inicia sesión</h4>
# <form action="/Account/LogIn" id="frmLogin" method="post"> <form class="col s12" id="floating-login-form">
# <div class="row">
# <div class="input-field col s11">
# <input class="form-control brd-rd-0" id="username-login1" name="username" placeholder="Usuario" style="padding:4px;" type="text"/>
# </div>
# </div>
# <div class="row">
# <div class="input-field col s11">
# <input class="form-control brd-rd-0" id="password-login1" name="password" placeholder="Contraseña" style="padding:4px;" type="password"/>
# </div>
# </div>
# <div id="reCaptchaLogin1">
# <input id="g-recaptcha-responselogin1" name="g-recaptcha-response" type="hidden"/>
# </div>
# <div class="row">
# <div class="input-field col s11">
# <button class="btn-tui-blue" id="loginButton" onclick="handleLogin()" type="button" value="Accede">Accede</button>
# <br/>
# <a href="/Account/ForgotPassword/">¿Has olvidado la contraseña?</a>
# </div>
# </div>
# </form>
# </form>
# <script src="https://www.google.com/recaptcha/api.js?render=6LdpiM8UAAAAAM210zQdB7PwQtgnvC8iMxX7Qci6"></script>
# <script>
#                                 async function handleLogin() {
#                                     try {
#                                         const loginButton = document.getElementById('loginButton');
#                                         loginButton.disabled = true;
#                                         const token = await generateRecaptchaToken();
#                                         document.getElementById('g-recaptcha-responselogin1').value = token;
#                                         document.getElementById('frmLogin').submit();
#
#                                     } catch (error) {
#                                         loginButton.disabled = false;
#                                     }
#                                 }
#
#                                 function generateRecaptchaToken() {
#                                     return new Promise((resolve, reject) => {
#                                         grecaptcha.ready(() => {
#                                             grecaptcha.execute('6LdpiM8UAAAAAM210zQdB7PwQtgnvC8iMxX7Qci6', { action: 'login' })
#                                                 .then(token => resolve(token))
#                                                 .catch(error => reject(error));
#                                         });
#                                     });
#                                 }
#                             </script>
# </div>
# <div class="col-md-6">
# <h4>Registro</h4>
# <div class="col s11">
# <h5>¿Eres un nuevo agente?</h5>
# <p>Somos un turoperador dirigido a agencias de viajes. Si eres un nuevo agente regístrate aquí.</p>
# <div class="input-field col s4" style="">
# <a class="btn-tui-blue-link" href="/Account/Registro/" style="line-height:inherit;margin-top: 15px;">Regístrate</a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-footer" style="padding:7px;">
# </div>
# </div>
# </div>
# </div>
# <!--  Modal PRESUPUESTOS y Reservas-->
# <div aria-hidden="true" class="modal fade hmodal-info tui-darkblue" id="modalPresupuestos" role="dialog" style="border-radius:0px;" tabindex="-2">
# <div class="modal-dialog modal-login">
# <div class="modal-personalizado modal-content">
# <div class="color-line"></div>
# <div class="modal-header" style="padding:5px;">
# <button aria-label="Close" class="close" data-dismiss="modal" style="margin:5px;" title="Cerrar" type="button"><span aria-hidden="true">x</span></button>
# <h4 class="modal-title" style="margin:10px;margin-bottom:-10px;"> Busca tus prespuestos y reservas</h4>
# <small class="font-bold" id="moTitle2" name="moTitle" style="padding-left:5px;" value=""></small>
# </div>
# <div class="modal-body col-md-12">
# <div class="col-md-6 border-right-only" style="padding-bottom: 20px;">
# <h4>Presupuesto</h4>
# <div class="row col-md-12">
# <div class="input-field">
# ...
#             enviaFiltros();
#         }
#
#         function marcaDur(event, id) {
#             var idcheck = id
#             var checked = document.getElementById(event.target.id).checked;
#             if (checked) {
#                 durs.push(id);
#             } else { //remove id lista
#                 for (var i = 0; i < durs.length; i++) {
#                     if (durs[i] === idcheck) {
#                         durs.splice(i, 1);
#                     }
#                 }
#             }
#
#             //console.log("---- duraciones marcadas: ----");
#             //for (var i = 0; i < durs.length; i++) {
#             //    console.log(durs[i]);
#             //}
#             enviaFiltros();
#         }
#
#         function muestraLista() {
#             $(".lista").toggle(true);
#             $(".bloques").toggle(false);
#         }
#
#         function muestraBloques() {
#             $(".bloques").toggle(true);
#             $(".lista").toggle(false);
#         }
#
#
#     </script>
# <script cookie-consent="functionality">
#
#         function resetearRecaptcha() {
#             $.ajax({
#                 type: "GET",
#                 url: '/Account/LoginForm',
#                 success: function (response) {
#                 $('#reCaptchaLogin1').html(response);
#                 var compruebaRecaptcha = setInterval(function() {
#                 if ($('#g-recaptcha-response').val() != '' && $('#g-recaptcha-response').val() != undefined) {
#                 clearInterval(compruebaRecaptcha);
#                 $('#recaptcha').removeAttr("disabled");
#                 }
#                 }, 1000);
#                 },
#                 error: function (result) {
#                 $('#reCaptchaLogin1').html('');
#                 }
#             });
#         }
#
#
#         $(function () {
#
#             if ($("#idcheckmantenimiento").val() == "Mantenimiento") {
#                 $("#idBotonlogin").click();
#             }
#
#
#             //$("#select-search").autocomplete({
#             //        source: "/Ajax/Search"
#             //    });
#
#             //ControlCookies();
#             //$('#btn-search').click(function () {
#             //    var gw2 = documente.getElementById('select-search');
#             //});
# //$("#select-search").autocomplete({
# //    source: function (request, response) {
# //        $.ajax({
# //            url: "/Home/Search", type: "POST", dataType: "json",
# //            //original code
# //            //data: { searchText: request.id, maxResults: 10 },
# //            //updated code; updated to request.term
# //            //and removed the maxResults since you are not using it on the server side
# //            data: { srch: request.term },
#
# //            success: function (data) {
# //                response($.map(data, function (item) {
# //                    //original code
# //                    //return { label: item.FullName, value: item.FullName, id: item.TagId };
# //                    //updated code
# //                    return { label: item.label, value: item.label, id: item.id };
# //                }));
# //            },
# //        select: function (event, ui) {
# //                //update the jQuery selector here to your target hidden field
# //            $("input[type=hidden]").val(ui.item.id);
# //        }
# //        });
# //    },
# //});
#
#             //var availableTags = ["ActionScript", "AppleScript", "Asp", "BASIC", "C", "C++", "Clojure", "COBOL", "ColdFusion", "Erlang", "Fortran", "Groovy", "Haskell", "Java", "JavaScript", "Lisp", "Perl", "PHP", "Python", "Ruby", "Scala", "Scheme"];
#             //$("#select-search").autocomplete({ source: availableTags });
#             //$("#select-search").on("keyup", function () {
#             //    var term = $(this).val();
#             //    $(this).autocomplete("destroy");
#             //    console.log(term);
#             //    $(this).autocomplete({ source: availableTags });
#
#             //});
#             //var miResponse;
#
#             $("#select-search").autocomplete({
#                 source: function (request, response) {
#                     //console.log(request);
#                     console.log(response);
#                     $.ajax( {
#                       url: "/Home/Search",
#                       dataType: "json",
#                       type: "POST",
#                       data: {
#                         term: request.term
#                       },
#                         success: function (data) {
#                             //alert(data);
#                             console.log(data);
#                             response( data );
#                         },
#                         error: function (err) {
#                             //alert("error");
#                             console.log(err);
#                         }
#                     });
#                   },
#                     minLength: 2
#             });
#
#            $('#modalpres').click(function () {
#                     bootbox.dialog({
#                             title: 'Por favor, introduzca el localizador del presupuesto:',
#                             message: "<input type='text' id='inputLocalicer' class='form-control' placeholder='XAAA1A1-00' /> </br> <p style='font-size:16px;'>O accede al <a href='/Agency/ListBookings'> <b>listado de reservas</b>.</a></p>",
#                             buttons: {
#                                 ok: {
#                                     label: "Enviar",
#                                     className: 'btn-info',
#                                     callback: function (item) {
#                                         var xd = document.getElementById('inputLocalicer');
#                                         var token = '';//document.getElementById('usuToken').value;
#                                         var link = 'https://reservas-online.es.tui.com/b2b/redirectionDeepLinkQuote.jsf?quoteReference=' + xd.value + '&UP=' + token;
#                                         if (xd.value)
#                                             window.location.href = link;  //redirige
#                                             //window.location.replace(link); //otra pestaña
#                                     }
#                                 }
#                             }
#                         });
#            });
#
#
#         });
#
#
#          function goToBooking() {
#              var loc = document.getElementById("idLoc").value;
#              if (loc) {
#                  document.getElementById("buscaReserva").href = "/Agency/BookingDetail/" + loc;
#                  document.getElementById("buscaReserva").click();
#              }
#              //else if (loc2) {
#              //    var link = "/Agency/BookingDetail?id=" + loc2;
#              //    window.open(link, "_self");
#              //}
#             //$.ajax({
#             //    type: "POST",
#             //    url: urlGetLocs + "?id="+loc,
#             //    success: function(msg) {
#             //    }
#             //});
#         }
#
#
#          function buscaViajeFreetext() {
#             var loc = document.getElementById("idBuscViajeDash").value;
#
#              console.log(loc);
#              if (loc) {
#                  var link = "/viajes?freeText=" + loc;
#                  window.open(link,"_self");
#              }
#              //else {
#              //    swal({ "Por favor, introduzca algún destino"});
#              //}
#
#             //$.ajax({
#             //    type: "POST",
#             //    url: urlGetLocs + "?id="+loc,
#             //    success: function(msg) {
#             //    }
#             //});
#         }
#
#
#     function goToQuotation() {
#         debugger;
#         var presu1 = document.getElementById('inputPresupuesto');
#             var presu2 = document.getElementById('inputPresupuestoDash');
#             var quotationId = "";
#             if (presu1.value || presu2.value) {
#                 if (presu1.value) {
#                     quotationId = presu1.value;
#                 } else if (presu2.value) {
#                     quotationId = presu2.value;
#                 }
#                 var link = "/Agency/QuoteInfo" + "?quotationId=" + quotationId;
#                 window.open(link, "_blank");
#             }
#     }
#
#         function chekKey(e) {
#             //See notes about 'which' and 'key'
#             if (e.keyCode == 13) { //si presiona enter
#                 goToBooking();
#             }
#         }
#         function chekKeyPresu(e) {
#             //See notes about 'which' and 'key'
#             if (e.keyCode == 13) { //si presiona enter
#                 goToQuotation();
#             }
#         }
#
#         function cambiaImgTV(element) {
#             var tipovviaje_back = element.id;
#             var default_img = "/images/demo/tipos-viaje.jpg";
#             if (tipovviaje_back) {
#                 $('#img_tipoViaje').attr('src', tipovviaje_back);
#                 //document.getElementById('img_tipoViaje').src == tipovviaje_back;
#                 //console.log(document.getElementById('img_tipoViaje').src);
#             }
#             //else {
#             //    document.getElementById('img_tipoViaje').src = default_img;
#             //}
#         }
#
#         //Modal contáctanos inicio
#         $("#btnClose").click(function () {
#             $("#modalContacto").hide();
#         });
#         function cambiarTexto() {
#             $("#labelUno").html("<a class='labelContacto linkContacto' href='mailto:info.ts@tui.com'>info.ts@tui.com</a>");
#             $("#labelDos").html("<a class='labelContacto linkContacto' href='tel://+34917582828'>+34 91 758 2828</a>");
#         }
#
#         //$(".b_packages").click(function () {   //Angel 15/04/2020 - Lo comento por que está haciendo que fallen todos los enlaces con target = "_blank" de la web"
#         //    var location = $(this).find("a").attr("href");
#
#         //    if (location != undefined && location != null) {
#         //        window.location = location;
#         //    }
#
#         //    return false;
#         //});
#
#         ///////////////////////////// COOKIES  (ANTIGUO)//////////////////////////////
#         //function ControlCookies() {
#         //    if (localStorage.controlcookie > 0) {
#         //        console.log(localStorage.controlcookie);
#         //        $('#modalCookies').hide();
#         //    } else
#         //         $('#modalCookies').show();
#
#         //}
#         //function aceptaCookies() {
#         //    // si variable no existe se crea (al clicar en Aceptar)
#         //    localStorage.controlcookie = (localStorage.controlcookie || 0);
#         //    // incrementamos cuenta de la cookie
#         //    localStorage.controlcookie++;
#         //    //cierro mensaje
#         //      $('#modalCookies').hide();
#         //    console.log("El usuario aceptó las cookies");
#         //}
#         //function CancelarCookies() {  //por el momento no lo estamos usando
# 	       // console.log("rrr")
#         //    cookies.style.display = 'none';
#         //}
#
#         //-----
#          //var settings = {
#          //       message: 'Esta web utiliza cookies para mejorar la experiencia y proporcionar funcionalidades adicionales.. <b> ás información ',
#          //       moreLinkLabel: 'aquí.</b>',
#          //       messageMaxHeightPercent: 30,
#          //       moreLink: '/Content/View/politica-privacidad/',
#          //       delay: 1000,
#          //       allowAdvancedOptions: true,
#          //       OnAccept: function () {
#          //           console.log('Yay! User accepted your cookies window!');
#          //           console.log('User preferences');
#          //           var preferences = $.fn.bsgdprcookies.GetUserPreferences();
#          //           console.log(preferences);
#
#          //       }
#          //   }
#
#          //   $(document).ready(function () {
#          //       $('body').bsgdprcookies(settings);
#          //       $("#modalCookies").on("show", function () {
#          //       $('#cookiesBtn').on('click', function () {
#          //           $('body').bsgdprcookies(settings, 'reinit');
#          //       });
#          //   });
#
#
#         /////////////////////////////////////////////////////////////////////////////
#
# </script>
# <style>
#
#         .grecaptcha-badge {
#             display: none !important;
#         }
#
#         .carousel-control {
#             width: 4%;
#         }
#
#             .carousel-control.left, .carousel-control.right {
#                 margin-left: 15px;
#                 background-image: none;
#             }
#
#         @media (max-width: 475px) {
#             .degradado {
#                 padding-top: 25%;
#             }
#         }
#
#         @media (min-width: 475px) and (max-width: 767px ) {
#             .degradado {
#                 padding-top: 50%;
#             }
#         }
#
#         @media (max-width: 767px) { /*Mobile*/
#             .carousel-inner .active.left {
#                 left: -100%;
#             }
#
#             .carousel-inner .next {
#                 left: 100%;
#             }
#
#             .carousel-inner .prev {
#                 left: -100%;
#             }
#
#             .active > div {
#                 /*display: none;*/
#             }
#
#                 .active > div:first-child {
#                     display: block;
#                 }
#
#             .search-view-mobile {
#                 display: initial;
#             }
#
#             .search-view-web {
#                 display: none;
#             }
#
#             .filter-view-mobile {
#                 display: initial;
#             }
#
#             .filter-view-web {
#                 display: none;
#             }
#             /*//modal cookies*/
#             .cc_dialog.interstitial {
#                 right: 5vw;
#                 top: 5vh;
#                 left: 5vw;
#                 max-width: 90%;
#                 position: fixed;
#                 max-height: 90%;
#                 overflow: auto;
#             }
#
#             .lista-flotante {
#                 display: none;
#             }
#             /*.mobile-scrollable {
#                 display: block;
#                 overflow-x: auto;
#             }*/
#         }
#
#         @media (min-width: 767px) and (max-width: 992px ) {
#             .carousel-inner .active.left {
#                 left: -50%;
#             }
#
#             .carousel-inner .next {
#                 left: 50%;
#             }
#
#             .carousel-inner .prev {
#                 left: -50%;
#             }
#
#             .active > div {
#                 /*display: none;*/
#             }
#
#                 .active > div:first-child {
#                     display: block;
#                 }
#
#                     .active > div:first-child + div {
#                         display: block;
#                     }
#
#             .search-view-mobile {
#                 display: initial;
#             }
#
#             .search-view-web {
#                 display: none;
#             }
#
#             .filter-view-mobile {
#                 display: initial;
#             }
#
#             .filter-view-web {
#                 display: none;
#             }
#
#             .degradado {
#                 padding-top: 0%;
#             }
#
#             .lista-flotante {
#                 display: block;
#             }
#         }
#
#         @media (min-width: 992px ) {
#             .carousel-inner .active.left {
#                 left: -25%;
#             }
#
#             .carousel-inner .next {
#                 left: 25%;
#             }
#
#             .carousel-inner .prev {
#                 left: -25%;
#             }
#
#             .filter-view-mobile {
#                 display: none;
#             }
#
#             .filter-view-web {
#                 display: block;
#             }
#         }
#
#         /*@media print
#         {
#             .no-print, .no-print *
#             {
#                 display: none !important;
#             }
#         }*/
#
#         .swal-wide-auto {
#             width: auto !important;
#         }
#
#         .swal-tui-blue {
#             padding: 2%;
#             background-color: #70cbf4 !important;
#             color: white;
#             font-family: 'TUITypeLt', sans-serif !important;
#             font-size: 18px !important;
#             text-align: justify;
#             width: 32%;
#         }
#
#         /*.mobile-scrollable {
#                 display: block;
#                 overflow-x: auto;
#             }*/
#
#     </style>
# </link></link></body>
# </html>

# %%
#Vamos a extraer todas los contenidos de la clase product-card
clase_product_card=sopa_argentina.find_all("div", {"class":"product-card"})
print(len(clase_product_card))
clase_product_card[0]
# Out:
# 23
# <div class="product-card">
# <a href="/viaje/triangulo-argentino" target="_self">
# <div class="v_place_img3" style="background: transparent url('https://statics.es.tui.com/staticFiles2/argentina_bright-colors-caminito-la-boca-neighborhood-181039046_-_minia939abf83a844a36806dd659672ad0df.png') no-repeat top center / 100% auto; min-height: 180px; border-radius: 15px 15px 0 0; padding: 5px;">
# <div class="product-card-tag">A tu Alcance</div>
# <div></div>
# </div>
# </a>
# <div class="product-card-text">
# <div class="product-card-text-title text-truncate-container">
# <a href="/viaje/triangulo-argentino" target="_self" title="Triángulo Argentino ">
# <span><strong>Triángulo Argentino </strong></span>
# </a>
# </div>
# <div class="product-card-text-duration text-truncate-container" title="10 Días / 7 Noches">
# <span>10 Días / 7 Noches</span>
# </div>
# <div class="product-card-text-description text-truncate-container-3l" title="Buenos Aires, El Calafate e Iguazú">
# <span>Itinerario: Buenos Aires, El Calafate e Iguazú</span>
# </div>
# </div>
# <div class="product-card-footer">
# <div class="col-lg-8 col-lg-8 col-sm-8 col-xs-8 product-card-footer-cell" style="font-size: 10px;">
#                 desde <span class="product-card-line-through-price"></span> <span class="product-card-price">2.265€</span>
# </div>
# <div class="col-lg-4 col-lg-4 col-sm-4 col-xs-4 product-card-footer-cell text-right">
# <a class="btn-tui-search-link-red product-card-footer-button rounded" href="/viaje/triangulo-argentino" style="" target="_self">Ver</a>
# </div>
# </div>
# </div>

# %%
#Planteo el diccionario con lo que quiero extraer:
dictio_scrap_1 = {"pais": [],
                                "nombre_viaje": [],
                                "duracion_viaje":[],
                                "itinerario":[],
                                "precio": [],
                                "fecha_escrapeo": datetime.now().date()}

# %%
def escrapeo_viajes_paises (pais):
    for viaje in clase_product_card:
        nombre_viaje=viaje.find("div", {"class": "product-card-text-title"}).get_text().replace("\n","").rstrip(" ")
        #print(nombre_viaje)
        duracion_viaje=viaje.find("div", {"class": "product-card-text-duration"}).get_text().replace("\n","").rstrip(" ")
        #print(duracion_viaje)
        itinerario = viaje.find("div", {"class": "product-card-text-description"}).get_text().replace("\n","").rstrip(" ").lstrip("Itinerario: ")
        #print(itinerario)
        precio = int(viaje.find("div", {"class": "product-card-footer"}).get_text().replace("\n","").rstrip(" ").lstrip("desde ").split('€')[0].replace(".",""))
        #print(precio)
        dictio_scrap_1["pais"].append(pais)
        dictio_scrap_1["nombre_viaje"].append(nombre_viaje)
        dictio_scrap_1["duracion_viaje"].append(duracion_viaje)
        dictio_scrap_1["itinerario"].append(itinerario)
        dictio_scrap_1["precio"].append(precio)
    return(dictio_scrap_1)

# %%
escrapeo_viajes_paises("Argentina")
df_australia = pd.DataFrame(escrapeo_viajes_paises("Argentina"))
df_australia
# Out:
#          pais                                       nombre_viaje  \
# 0   Argentina                                Triángulo Argentino
# 1   Argentina                             Patagonia a tu alcance
# 2   Argentina                    Ballenas, Glaciares y Cataratas
# 3   Argentina                 Buenos Aires, El Calafate e Iguazú
# 4   Argentina                                 Argentina y Brasil
# 5   Argentina                                   Argentina Mágica
# 6   Argentina                             Argentina a tu alcance
# 7   Argentina                       Lagos, Glaciares y Cataratas
# 8   Argentina                                  Argentina Clásica
# 9   Argentina                            Contrastes de Argentina
# 10  Argentina                             Argentina Espectacular
# 11  Argentina                               Patagonia Fascinante
# 12  Argentina                               Patagonia con Iguazú
# 13  Argentina                              Lo Mejor de Argentina
# 14  Argentina                                 Argentina para Dos
# 15  Argentina                      Patagonia Argentina y Chilena
# 21    5895     2025-04-06
# 22    6745     2025-04-06
# 23    2265     2025-04-06
# 24    2695     2025-04-06
# 25    2755     2025-04-06
# 26    2865     2025-04-06
# 27    2965     2025-04-06
# 28    3055     2025-04-06
# 29    3150     2025-04-06
# 30    3295     2025-04-06
# 31    3325     2025-04-06
# 32    3395     2025-04-06
# 33    3495     2025-04-06
# 34    3695     2025-04-06
# 35    3725     2025-04-06
# 36    4025     2025-04-06
# 37    4095     2025-04-06
# 38    4385     2025-04-06
# 39    4750     2025-04-06
# 40    5235     2025-04-06
# 41    5545     2025-04-06
# 42    5585     2025-04-06
# 43    5825     2025-04-06
# 44    5895     2025-04-06
# 45    6745     2025-04-06

# %%
destinos_totales = destinos_totales()
dictio_scrap_1 = {"pais": [],
                                "nombre_viaje": [],
                                "duracion_viaje":[],
                                "itinerario":[],
                                "precio": [],
                                "fecha_escrapeo": datetime.now().date()}
for pais in destinos_totales["nombre_pais"]:
    URL_ESCRAPEO_VIAJES_PAIS=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","-") #url original
    print(URL_ESCRAPEO_VIAJES_PAIS)
    sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS)
    clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
    print(len(clase_product_card))
    escrapeo_viajes_paises(pais)
    if len(clase_product_card) == 0: 
        URL_ESCRAPEO_VIAJES_PAIS_SIN_TILDE=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","-").replace("á","a").replace("Á","a").replace("é","e").replace("É","e").replace("í","i").replace("Í","i").replace("ó","o").replace("Ó","o").replace("ú","u").replace("Ú","u").replace("ñ","n").replace("ç","c")
        print(URL_ESCRAPEO_VIAJES_PAIS_SIN_TILDE)
        sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS)
        clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
        print(len(clase_product_card))
        escrapeo_viajes_paises(pais)
        if len(clase_product_card) == 0: 
            URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","")
            print(URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO)
            sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS)
            clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
            print(len(clase_product_card))
            escrapeo_viajes_paises(pais)
            if len(clase_product_card) == 0: 
                URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO_SIN_TILDE=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","").replace("á","a").replace("Á","a").replace("é","e").replace("É","e").replace("í","i").replace("Í","i").replace("ó","o").replace("Ó","o").replace("ú","u").replace("Ú","u").replace("ñ","n").replace("ç","c")
                print(URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO_SIN_TILDE)
                sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS)
                clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
                print(len(clase_product_card))
                escrapeo_viajes_paises(pais)
    pd.DataFrame(dictio_scrap_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 destinos_totales = destinos_totales()
#       2 dictio_scrap_1 = {"pais": [],
#       3                                 "nombre_viaje": [],
#       4                                 "duracion_viaje":[],
#       5                                 "itinerario":[],
#       6                                 "precio": [],
#       7                                 "fecha_escrapeo": datetime.now().date()}
#       8 for pais in destinos_totales["nombre_pais"]:
#
# TypeError: 'dict' object is not callable

# %%
pd.DataFrame(dictio_scrap_1)
# Out:
#           pais                                 nombre_viaje  \
# 0      Albania                         Albania y Montenegro
# 1     Alemania                                       Berlín
# 2     Alemania  Fly & Drive Austria, Entre Lagos y Montañas
# 3     Alemania             Fly & Drive Carlomagno a su aire
# 4     Alemania                Fly & Drive Tirol al Completo
# ...        ...                                          ...
# 1009  Zimbabue                          Río Perdido Clásico
# 1010  Zimbabue                    Ruta del Okavango Premium
# 1011  Zimbabue                Maravillas del África Austral
# 1012  Zimbabue                             Okavango Clásico
# 1013  Zimbabue                             Zimbabue Salvaje
#
#            duracion_viaje                                         itinerario  \
# 0       8 Días / 7 Noches  Tirana, Dürres, Berat, Kruja, Shkodër, Petrova...
# 1       4 Días / 3 Noches                                             Berlín
# 2       8 Días / 7 Noches  Salzburgo, Gmunden, Linz, Melk, Viena, Graz, H...
# 3      10 Días / 9 Noches  Bruselas, Durbuy, Lieja, Aquisgrán, Colonia, B...
# 4       8 Días / 7 Noches  sbruck, Cataratas Krimml, Vipiteno, Bresanona,...
# ...                   ...                                                ...
# 1009  16 Días / 13 Noches  Cataratas Victoria, Valle de los Elefantes, P....
# 1010  21 Días / 18 Noches  Windhoek, Desierto de Namibia, Sossusvlei, Ses...
# 1011  16 Días / 13 Noches  Windhoek, Desierto de Namibia, Cataratas Victo...
# 1012  24 Días / 21 Noches  Ciudad del Cabo, Windhoek, Desierto de Namibia...
# 1013   11 Días / 8 Noches        Cataratas Victoria, P.N Hwange y Mana Pools
#
#       precio fecha_escrapeo
# 0       1755     2025-04-06
# 1        708     2025-04-06
# 2        827     2025-04-06
# 3        857     2025-04-06
# 4        894     2025-04-06
# ...      ...            ...
# 1009    4930     2025-04-06
# 1010    5335     2025-04-06
# 1011    5895     2025-04-06
# 1012    6045     2025-04-06
# 1013    6539     2025-04-06
#
# [1014 rows x 6 columns]

# %%
destinos_totales = destinos_totales()
dictio_scrap_1 = {"pais": [],
                                "nombre_viaje": [],
                                "duracion_viaje":[],
                                "itinerario":[],
                                "precio": [],
                                "fecha_escrapeo": datetime.now().date()}
for pais in destinos_totales["nombre_pais"]:
    print(pais)
    URL_ESCRAPEO_VIAJES_PAIS=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","-") #url original
    sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS)
    clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
    escrapeo_viajes_paises(pais)
    if len(clase_product_card) == 0: 
        URL_ESCRAPEO_VIAJES_PAIS_SIN_TILDE=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","-").replace("á","a").replace("Á","a").replace("é","e").replace("É","e").replace("í","i").replace("Í","i").replace("ó","o").replace("Ó","o").replace("ú","u").replace("Ú","u").replace("ñ","n").replace("ç","c")
        sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS_SIN_TILDE)
        clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
        escrapeo_viajes_paises(pais)
        if len(clase_product_card) == 0: 
            URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","")
            sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO)
            clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
            escrapeo_viajes_paises(pais)
            if len(clase_product_card) == 0: 
                URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO_SIN_TILDE=os.getenv("URL_ESCRAPEO_VIAJES_PAISES")+pais.replace(" ","").replace("á","a").replace("Á","a").replace("é","e").replace("É","e").replace("í","i").replace("Í","i").replace("ó","o").replace("Ó","o").replace("ú","u").replace("Ú","u").replace("ñ","n").replace("ç","c")
                sopa_pais= crear_sopa(URL_ESCRAPEO_VIAJES_PAIS_SIN_ESPACIO_SIN_TILDE)
                clase_product_card=sopa_pais.find_all("div", {"class":"product-card"})  #Vamos a extraer todas los contenidos de la clase product-card
                escrapeo_viajes_paises(pais)
print("El escrapeo ha finalizado, la información de todos los destinos ha sido obtenida")
df_escrapeo_viajes = pd.DataFrame(dictio_scrap_1)
df_escrapeo_viajes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 destinos_totales = destinos_totales()
#       2 dictio_scrap_1 = {"pais": [],
#       3                                 "nombre_viaje": [],
#       4                                 "duracion_viaje":[],
#       5                                 "itinerario":[],
#       6                                 "precio": [],
#       7                                 "fecha_escrapeo": datetime.now().date()}
#       8 for pais in destinos_totales["nombre_pais"]:
#
# TypeError: 'dict' object is not callable

# %%
#Escrapeo del continente de cada destino:
url_argentina = "https://es.tui.com/viajes/Alemania"
# Accedemos a la url
res_argentina=rq.get(url_argentina)
# Comprobamos que tenemos una respuesta correcta
res_argentina.status_code
# Creamos la sopa
sopa_argentina=bs(res_argentina.content,"html.parser")
sopa_argentina
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <!-- Consent Mode de Google, permite hacer un tracking de visitantes activos aunque no acepten las cookies -->
# <!-- Cookie Consent by https://www.FreePrivacyPolicy.com -->
# <script src="/vendor/cookieConsent/cookie-consent.js"></script>
# <script type="text/javascript">
#         document.addEventListener('DOMContentLoaded', function () {
#             cookieconsent.run({ "notice_banner_type": "interstitial", "consent_type": "express", "palette": "light", "language": "es", "website_name": "TUI", "cookies_policy_url": "https://es.tui.com/politica-privacidad" });
#         });
#     </script>
# <!-- End Cookie Consent -->
# <!-- Google Tag Manager -->
# <script cookie-consent="tracking" type="text/plain">
#         (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-54HQHT');
#
#         function prepairQuotation() {
#         console.log(item);
#         console.log(token);
#         var token = '';
#         var link = 'https://reservas-online.es.tui.com/b2b/redirectionDeepLinkQuote.jsf?quoteReference=' + xd.value + '&UP=' + token;
#         document.getElementById('btnEnvio').href = link;
#         }
#     </script>
# <!-- Page hiding snippet (recommended) -->
# <style>
#         .async-hide {
#             /*opacity: 0 !important*/
#         }
#
#         /*.ui-autocomplete-loading {
#             background: url(images/load-loading.gif) no-repeat left center #fff !important;
#             background-size: 40% !important;
#             background-position-x: -72px !important;
#         }*/
#     </style>
# <script cookie-consent="tracking" type="text/plain">
#         (function (a, s, y, n, c, h, i, d, e) {
#         s.className += ' ' + y;
#         h.end = i = function () { s.className = s.className.replace(RegExp(' ?' + y), '') };
#         (a[n] = a[n] || []).hide = h; setTimeout(function () { i(); h.end = null }, c);
#         })(window, document.documentElement, 'async-hide', 'dataLayer', 4000, { 'GTM-54HQHT': true });
#     </script>
# <!-- End Google Tag Manager -->
# <script>
#         var hideMenuSpecialDepartures = false;
#         var hideMenuTrìpTypes = false;
#     </script>
# <script cookie-consent="functionality" src="https://cdn.jsdelivr.net/npm/sweetalert2@9"></script>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="true" name="HandheldFriendly"/>
# <title>Europa-Alemania</title>
# <!-- FAV ICON -->
# <link href="/images/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/images/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/images/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/images/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/images/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/images/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/images/favicon/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/images/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- FONT-AWESOME ICON CSS -->
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <!--== ALL CSS FILES ==-->
# <link href="/css/jquery-ui.min.css" rel="stylesheet">
# <link href="/css/style.css?v=1.78.8.020250408171711" rel="stylesheet"/>
# <link href="/css/hero.css?v=1.78.8.020250408171711" rel="stylesheet"/>
# <link href="/css/materialize.css" rel="stylesheet"/><!-- NO tocar ni cambiar de versión, se van a la mierda el diseño-->
# <!-- v2-->
# <link href="/vendor/bootstrap/dist/css/bootstrap.css" rel="stylesheet"> <!-- v3.3.7-->
# <link href="/css/mob.css" rel="stylesheet"/>
# <link href="/css/animate.css" rel="stylesheet"/>
# <link href="/css/iconos-tui.css" rel="stylesheet"/>
# <link href="/vendor/metisMenu/dist/metisMenu.css" rel="stylesheet">
# <link href="/vendor/select2-3.5.2/select2b.css" rel="stylesheet">
# <!-- ==DATATABLES ==-->
# <link href="/vendor/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet">
# <link href="/vendor/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet">
# <link href="/vendor/datatables.net-buttons-bs/css/buttons.bootstrap.min.css" rel="stylesheet">
# <!-- Datetimepicker -->
# <link href="/js/bootstrap-datetimepicker-master/bootstrap-datetimepicker.css" rel="stylesheet">
# <!-- Datepicker -->
# <link href="/js/bootstrap-datepicker-1.9.0-dist/css/bootstrap-datepicker.css" rel="stylesheet">
# <!-- NanoScroller -->
# <link href="/vendor/nanoscroller/css/nanoscroller.min.css" rel="stylesheet">
# <!-- Slick -->
# <link href="/vendor/slick/slick.css" rel="stylesheet">
# <!-- FancyBox -->
# <link href="/vendor/fancybox/jquery.fancybox.css" rel="stylesheet">
# <!-- Fontawesome -->
# <link href="/vendor/fontawesome/css/font-awesome.css" rel="stylesheet">
# </link></link></link></link></link></link></link></link></link></link></link></link></link></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-54HQHT" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Preloader -->
# <!-- MOBILE MENU -->
# <section id="idMobileMenuSection">
# <div class="ed-mob-menu" data-offset-top="33" data-spy="affix">
# <div class="ed-mob-menu-con">
# <div class="ed-mm-left">
# <div class="wed-logo">
# <a href="/">
# <svg class="main-nav__icon-tui / u-pos-abs" height="57" width="80" xmlns="http://www.w3.org/2000/svg"> <path d="m79.57487,39.14251c0.07732,-0.06247 0.1343,-0.13275 0.17093,-0.21085s0.05291,-0.19523 0.05291,-0.34751l0,-11.4052c0,-0.15618 -0.01628,-0.27332 -0.05291,-0.35531s-0.0936,-0.14837 -0.17093,-0.20304c-0.18313,-0.13666 -0.59824,-0.20694 -1.25345,-0.20694c-0.66742,0 -1.09067,0.07028 -1.2738,0.20694c-0.07732,0.05466 -0.1343,0.12495 -0.17093,0.20304s-0.05291,0.19913 -0.05291,0.35531l0,11.4052c0,0.2538 0.07325,0.44121 0.22383,0.55835c0.18313,0.13666 0.60638,0.20694 1.2738,0.20694c0.65522,0 1.07032,-0.07028 1.25345,-0.20694zm-8.86779,0.06638c0.67963,-0.22256 1.23718,-0.53492 1.6767,-0.93319s0.75696,-0.86681 0.96044,-1.41345s0.30522,-1.13622 0.30522,-1.77657l0,-7.91062c0,-0.26551 -0.07325,-0.45293 -0.21569,-0.55835c-0.19534,-0.13666 -0.61045,-0.20694 -1.25345,-0.20694c-0.66742,0 -1.09067,0.07028 -1.2738,0.20694c-0.08546,0.05466 -0.14244,0.12495 -0.175,0.20304s-0.04884,0.19913 -0.04884,0.35531l0,7.87548c0,0.31236 -0.05698,0.62863 -0.17093,0.
# </a>
# </div>
# </div>
# <div class="ed-mm-right">
# <div class="ed-mm-menu">
# <a class="ed-micon" href="#"><i class="fa fa-bars"></i></a>
# <div class="ed-mm-inn tui-bck-blue60">
# <div class="text-right">
# <a class="ed-mi-close" href="#"><i class="fa fa-times"></i></a>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(6);">
#                                 Destinos
#                                         <img id="iconMobileMenu-6" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-6" style="display:none;">
# <ul>
# <li>
# <a class="destinationitem destinationitem1442" data-destid="1442" href="/buscador-destinos/europa" style="text-transform: none;">Europa</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1443" data-destid="1443" href="/buscador-destinos/africa" style="text-transform: none;">África</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1444" data-destid="1444" href="/buscador-destinos/asia" style="text-transform: none;">Asia</a>
# </li>
# <li>
# <a class="destinationitem destinationitem628" data-destid="628" href="/buscador-destinos/oriente-medio" style="text-transform: none;">Oriente Medio</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1447" data-destid="1447" href="/buscador-destinos/islas-exoticas" style="text-transform: none;">Islas Exóticas</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1445" data-destid="1445" href="/buscador-destinos/oceania" style="text-transform: none;">Oceanía</a>
# </li>
# <li>
# <a class="destinationitem destinationitem1441" data-destid="1441" href="/buscador-destinos/america" style="text-transform: none;">América</a>
# </li>
# <li>
# <a class="destinationitem destinationitem114" data-destid="114" href="/buscador-destinos/caribe" style="text-transform: none;">Caribe</a>
# </li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(7);">
#                                 Catálogos
#                                         <img id="iconMobileMenu-7" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-7" style="display:none;">
# <ul>
# <li><a href="/catalogos" style="text-transform: none;">Catálogos</a></li>
# <li><a href="/Boletines-de-ofertas" style="text-transform: none;">Boletines de Ofertas</a></li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(8);">
#                                 Ofertas
#                                         <img id="iconMobileMenu-8" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-8" style="display:none;">
# <ul>
# <li><a href="/ofertas">Ofertas</a></li>
# <li><a href="/viajes?tag=rumbo-a-asia-oriental">Rumbo a Asia Oriental</a></li>
# </ul>
# </div>
# <h4>
# <a class="mm-arr mr-2" href="/viajes?tag=al-completo">
#                                     Al Completo
#                                 </a>
# </h4>
# <h4>
# <a class="mm-arr mr-2" href="/viajes?tag=a-tu-alcance">
#                                     A tu Alcance
#                                 </a>
# </h4>
# <h4>
# <a class="mm-arr mr-2" href="javascript:void(0);" onclick="mostrarCapaMenuMobile(105);">
#                                 Salidas Garantizadas
#                                         <img id="iconMobileMenu-105" src="/images/svg/mobile-icons/arrow-down-sign-to-navigate.svg" style="max-width: 13px; margin-left: 6px;"/>
# </a>
# </h4>
# <div id="subMobileMenu-105" style="display:none;">
# <ul>
# <li><a href="/viajes?tag=cruceros-fluviales">Cruceros Fluviales</a></li>
# <li><a href="/viajes?tag=semana-santa">Semana Santa</a></li>
# <li><a href="/viajes?tag=puente-de-mayo">Puente de Mayo</a></li>
# <li><a href="/viajes?tag=salidas-garantizadas">Todas las Salidas Garantizadas</a></li>
# </ul> </div>
# <div class="mt-2">
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/quienes-somos-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/quienes-somos">Quiénes Somos</a>
# </h4>
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/contacto-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/contactanos">Contáctanos</a>
# </h4>
# <h4>
# <img class="mr-1" src="/images/svg/mobile-icons/trabaja-con-nosotros-icon-menu-mobile.svg" style="max-width: 23px;"/>
# <a class="mm-arr mr-2" href="/trabaja-con-nosotros">Trabaja con nosotros</a>
# </h4>
# <div>
# <a class="btn-tui-darkblue-login" data-target="#modalLogin" data-toggle="modal" href="#modalLogin" id="idBotonlogin" title="Login/Registro"> Acceso agencias</a>
# </div>
# <div class="mobile-social-media foot-social foot-com">
# <div>Síguenos en redes</div>
# <ul>
# <li><a href="https://www.facebook.com/tuispain" target="_blank"><span class="fa fa fa-facebook"></span></a> </li>
# <li><a href="https://www.instagram.com/tuispain/?hl=es" target="_blank"><span class="fa fa fa-instagram"></span></a> </li>
# <li><a href="https://es.linkedin.com/company/tuigroup" target="_blank"><span class="fa fa fa-linkedin"></span></a> </li>
# <li><a href="https://www.youtube.com/user/TuiSpain" target="_blank"><span class="fa fa fa-youtube"></span></a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></section>
# <style>
#     .rotated {
#         transform: rotate(180deg);
#         -ms-transform: rotate(180deg); /* IE 9 */
#         -moz-transform: rotate(180deg); /* Firefox */
#         -webkit-transform: rotate(180deg); /* Safari and Chrome */
#         -o-transform: rotate(180deg); /* Opera */
#     }
#
# </style>
# <script>
#
#     function mostrarCapaMenuMobile(itemId) {
#         $('#subMobileMenu-' + itemId).slideToggle();
#         if ($('#iconMobileMenu-' + itemId).hasClass("rotated")) {
#             $('#iconMobileMenu-' + itemId).removeClass("rotated");
#         } else {
#             $('#iconMobileMenu-' + itemId).addClass("rotated");
#         }
#     }
# </script>
# <!--HEADER SECTION-->
# <section id="idMenuSection">
# <!-- TOP BAR -->
# <!-- LOGO AND MENU SECTION -->
# <div class="top-logo" data-offset-top="33" data-spy="affix">
# <div class="container">
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Grecia Clásica
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/grecia-clasica';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1443" data-destinationid="1443" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">África</h4></div>
# <ul>
# <li><a href="/viajes/botsuana" style="text-transform: none;">Botsuana</a></li>
# <li><a href="/viajes/cabo-verde" style="text-transform: none;">Cabo Verde</a></li>
# <li><a href="/viajes/egipto" style="text-transform: none;">Egipto</a></li>
# <li><a href="/viajes/kenia" style="text-transform: none;">Kenia</a></li>
# <li><a href="/viajes/madagascar" style="text-transform: none;">Madagascar</a></li>
# <li><a href="/viajes/marruecos" style="text-transform: none;">Marruecos</a></li>
# <li><a href="/viajes/namibia" style="text-transform: none;">Namibia</a></li>
# <li><a href="/viajes/reunion" style="text-transform: none;">Reunión</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/ruanda" style="text-transform: none;">Ruanda</a></li>
# <li><a href="/viajes/sudafrica" style="text-transform: none;">Sudáfrica</a></li>
# <li><a href="/viajes/tanzania" style="text-transform: none;">Tanzania</a></li>
# <li><a href="/viajes/tunez" style="text-transform: none;">Túnez</a></li>
# <li><a href="/viajes/uganda" style="text-transform: none;">Uganda</a></li>
# <li><a href="/viajes/zimbabue" style="text-transform: none;">Zimbabue</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Jambo_box953cc55869b84f359624323d345adf16.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Safari Jambo
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/safari-jambo-opciones';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1444" data-destinationid="1444" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Asia</h4></div>
# <ul>
# <li><a href="/viajes/butan" style="text-transform: none;">Bután</a></li>
# <li><a href="/viajes/turquía" style="text-transform: none;">Turquía</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Dubai_Maldivas_new_box6f9eab0d295b4db791c90d3b840ffd0153e57937a7f44b17a5a52cfabd2363af.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Dubái y Maldivas
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/dubai-y-maldivas';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1447" data-destinationid="1447" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Islas Exóticas</h4></div>
# <ul>
# <li><a href="/viajes/fiji" style="text-transform: none;">Fiji</a></li>
# <li><a href="/viajes/islas-cook" style="text-transform: none;">Islas Cook</a></li>
# <li><a href="/viajes/maldivas" style="text-transform: none;">Maldivas</a></li>
# <li><a href="/viajes/mauricio" style="text-transform: none;">Mauricio</a></li>
# <li><a href="/viajes/nueva-caledonia" style="text-transform: none;">Nueva Caledonia</a></li>
# <li><a href="/viajes/polinesia-francesa" style="text-transform: none;">Polinesia Francesa</a></li>
# <li><a href="/viajes/samoa" style="text-transform: none;">Samoa</a></li>
# <li><a href="/viajes/seychelles" style="text-transform: none;">Seychelles</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/zanzibar" style="text-transform: none;">Zanzíbar</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Dubai_Maldivas_new_box6f9eab0d295b4db791c90d3b840ffd0153e57937a7f44b17a5a52cfabd2363af.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Dubái y Maldivas
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/dubai-y-maldivas';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1445" data-destinationid="1445" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">Oceanía</h4></div>
# <ul>
# <li><a href="/viajes/australia" style="text-transform: none;">Australia</a></li>
# <li><a href="/viajes/nueva-zelanda" style="text-transform: none;">Nueva Zelanda</a></li>
# <li><a href="/viajes/papuanuevaguinea" style="text-transform: none;">Papúa Nueva Guinea</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px;  border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Diseño_sin_título_-_2022-02-23T151554.782d29038cf5ba242a4899c4beaeca12b36.jpg"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Australia en autocaravana - Ruta A
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/australia-en-autocaravana-ruta-a';">Ver producto</button>
# </div>
# </div>
# </div>
# <div class="no-icon-before countryitem countryitem1441" data-destinationid="1441" style="display: none;">
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px;  margin-top: 10px;">
# <div style="min-height: 15px; margin-left: 20px; font-weight: bold;"><h4 style="border-bottom: 0;">América</h4></div>
# <ul>
# <li><a href="/viajes/argentina" style="text-transform: none;">Argentina</a></li>
# <li><a href="/viajes/belice" style="text-transform: none;">Belice</a></li>
# <li><a href="/viajes/bolivia" style="text-transform: none;">Bolivia</a></li>
# <li><a href="/viajes/brasil" style="text-transform: none;">Brasil</a></li>
# <li><a href="/viajes/canada" style="text-transform: none;">Canadá</a></li>
# <li><a href="/viajes/chile" style="text-transform: none;">Chile</a></li>
# <li><a href="/viajes/colombia" style="text-transform: none;">Colombia</a></li>
# <li><a href="/viajes/costa-rica" style="text-transform: none;">Costa Rica</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/ecuador" style="text-transform: none;">Ecuador</a></li>
# <li><a href="/viajes/elsalvador" style="text-transform: none;">El Salvador</a></li>
# <li><a href="/viajes/estados-unidos" style="text-transform: none;">Estados Unidos</a></li>
# <li><a href="/viajes/guatemala" style="text-transform: none;">Guatemala</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3" style="padding:10px; border-left: 1px solid #eaeaea; border-right:0px; margin-top: 55px;">
# <div style=""></div>
# <ul>
# <li><a href="/viajes/turksandcaicos" style="text-transform: none;">Turks and Caicos</a></li>
# </ul>
# </div>
# <div class="mm1-com mm1-cour-com mm1-s3 destino-destacado" style="border-left: 1px solid #eaeaea;border-right:0px; margin-top: 20px;">
# <div class="destino-destacado-titulo">
#                         Producto destacado
#                     </div>
# <div>
# <img class="img-responsive" src="https://statics.es.tui.com/staticFiles2/Tesoros_de_México_-miniatura9812514644ad446e9f41ab81d9d733e8.webp"/>
# </div>
# <div class="destino-destacado-titulo-producto">
#                         Tesoros de México
#                     </div>
# <div>
# <button class="btn btn-rojo" onclick="javascript:location.href='/viaje/tesoros-de-mexico';">Ver producto</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </li>
# <li class="cour-menu" style="">
# <a class="mm-arr" href="/catalogos">Catálogos</a>
# <div class="mm-pos" style="left:inherit">
# <div class="cour-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/catalogos">Catálogos</a></li>
# <li><a href="/Boletines-de-ofertas">Boletines de Ofertas</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="ofer-menu" style="">
# <a class="mm-arr" href="/ofertas">Ofertas</a>
# <div class="mm-pos" style="left:inherit">
# <div class="ofer-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/ofertas">Ofertas</a></li>
# <li><a href="/viajes?tag=rumbo-a-asia-oriental">Rumbo a Asia Oriental</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="" style="">
# <a class="mm-arr" href="/viajes?tag=al-completo">Al Completo</a>
# </li>
# <li class="" style="">
# <a class="mm-arr" href="/viajes?tag=a-tu-alcance">A tu Alcance</a>
# </li>
# <li class="admi-menu" style="">
# <a class="mm-arr" href="/viajes?tag=salidas-garantizadas">Salidas Garantizadas</a>
# <div class="mm-pos" style="left:inherit">
# <div class="admi-mm m-menu" style="width:20%;margin-top:-7px;">
# <div class="m-menu-inn">
# <div class="mm1-com mm1-s2" style="border:0px;width:auto;">
# <ul class="col-md-12">
# <li><a href="/viajes?tag=cruceros-fluviales">Cruceros Fluviales</a></li>
# <li><a href="/viajes?tag=semana-santa">Semana Santa</a></li>
# <li><a href="/viajes?tag=puente-de-mayo">Puente de Mayo</a></li>
# <li><a href="/viajes?tag=salidas-garantizadas">Todas las Salidas Garantizadas</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li id="openBtn2">
# </li>
# <div class="wed-login">
# <a class="btn-tui-darkblue-login" data-target="#modalLogin" data-toggle="modal" href="#modalLogin" id="idBotonlogin" title="Login/Registro"> Acceso agencias</a>
# </div>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--  Modal LOGIN-->
# <div aria-hidden="true" class="modal fade hmodal-info tui-darkblue" id="modalLogin" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-login">
# <div class="modal-personalizado modal-content">
# <div class="color-line"></div>
# <div class="modal-header" style="padding:5px;">
# <button aria-label="Close" class="close" data-dismiss="modal" style="margin:5px;" title="Cerrar" type="button"><span aria-hidden="true">x</span></button>
# <h4 class="modal-title" style="margin:10px;margin-bottom:-10px;"> ¡Bienvenido! </h4>
# <small class="font-bold" id="moTitle2" name="moTitle" style="padding-left:5px;" value=""></small>
# </div>
# <div class="modal-body col-md-12" id="login-form">
# <div class="col-md-6 border-right-only">
# <h4>Inicia sesión</h4>
# <form action="/Account/LogIn" id="frmLogin" method="post"> <form class="col s12" id="floating-login-form">
# <div class="row">
# <div class="input-field col s11">
# <input class="form-control brd-rd-0" id="username-login1" name="username" placeholder="Usuario" style="padding:4px;" type="text"/>
# </div>
# </div>
# <div class="row">
# <div class="input-field col s11">
# <input class="form-control brd-rd-0" id="password-login1" name="password" placeholder="Contraseña" style="padding:4px;" type="password"/>
# </div>
# </div>
# <div id="reCaptchaLogin1">
# <input id="g-recaptcha-responselogin1" name="g-recaptcha-response" type="hidden"/>
# </div>
# <div class="row">
# <div class="input-field col s11">
# <button class="btn-tui-blue" id="loginButton" onclick="handleLogin()" type="button" value="Accede">Accede</button>
# <br/>
# <a href="/Account/ForgotPassword/">¿Has olvidado la contraseña?</a>
# </div>
# </div>
# </form>
# </form>
# <script src="https://www.google.com/recaptcha/api.js?render=6LdpiM8UAAAAAM210zQdB7PwQtgnvC8iMxX7Qci6"></script>
# <script>
#                                 async function handleLogin() {
#                                     try {
#                                         const loginButton = document.getElementById('loginButton');
#                                         loginButton.disabled = true;
#                                         const token = await generateRecaptchaToken();
#                                         document.getElementById('g-recaptcha-responselogin1').value = token;
#                                         document.getElementById('frmLogin').submit();
#
#                                     } catch (error) {
#                                         loginButton.disabled = false;
#                                     }
#                                 }
#
#                                 function generateRecaptchaToken() {
#                                     return new Promise((resolve, reject) => {
#                                         grecaptcha.ready(() => {
#                                             grecaptcha.execute('6LdpiM8UAAAAAM210zQdB7PwQtgnvC8iMxX7Qci6', { action: 'login' })
#                                                 .then(token => resolve(token))
#                                                 .catch(error => reject(error));
#                                         });
#                                     });
#                                 }
#                             </script>
# </div>
# <div class="col-md-6">
# <h4>Registro</h4>
# <div class="col s11">
# <h5>¿Eres un nuevo agente?</h5>
# <p>Somos un turoperador dirigido a agencias de viajes. Si eres un nuevo agente regístrate aquí.</p>
# <div class="input-field col s4" style="">
# <a class="btn-tui-blue-link" href="/Account/Registro/" style="line-height:inherit;margin-top: 15px;">Regístrate</a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-footer" style="padding:7px;">
# </div>
# </div>
# </div>
# </div>
# <!--  Modal PRESUPUESTOS y Reservas-->
# <div aria-hidden="true" class="modal fade hmodal-info tui-darkblue" id="modalPresupuestos" role="dialog" style="border-radius:0px;" tabindex="-2">
# <div class="modal-dialog modal-login">
# <div class="modal-personalizado modal-content">
# <div class="color-line"></div>
# <div class="modal-header" style="padding:5px;">
# <button aria-label="Close" class="close" data-dismiss="modal" style="margin:5px;" title="Cerrar" type="button"><span aria-hidden="true">x</span></button>
# <h4 class="modal-title" style="margin:10px;margin-bottom:-10px;"> Busca tus prespuestos y reservas</h4>
# <small class="font-bold" id="moTitle2" name="moTitle" style="padding-left:5px;" value=""></small>
# </div>
# <div class="modal-body col-md-12">
# <div class="col-md-6 border-right-only" style="padding-bottom: 20px;">
# <h4>Presupuesto</h4>
# <div class="row col-md-12">
# <div class="input-field">
# ...
#             enviaFiltros();
#         }
#
#         function marcaDur(event, id) {
#             var idcheck = id
#             var checked = document.getElementById(event.target.id).checked;
#             if (checked) {
#                 durs.push(id);
#             } else { //remove id lista
#                 for (var i = 0; i < durs.length; i++) {
#                     if (durs[i] === idcheck) {
#                         durs.splice(i, 1);
#                     }
#                 }
#             }
#
#             //console.log("---- duraciones marcadas: ----");
#             //for (var i = 0; i < durs.length; i++) {
#             //    console.log(durs[i]);
#             //}
#             enviaFiltros();
#         }
#
#         function muestraLista() {
#             $(".lista").toggle(true);
#             $(".bloques").toggle(false);
#         }
#
#         function muestraBloques() {
#             $(".bloques").toggle(true);
#             $(".lista").toggle(false);
#         }
#
#
#     </script>
# <script cookie-consent="functionality">
#
#         function resetearRecaptcha() {
#             $.ajax({
#                 type: "GET",
#                 url: '/Account/LoginForm',
#                 success: function (response) {
#                 $('#reCaptchaLogin1').html(response);
#                 var compruebaRecaptcha = setInterval(function() {
#                 if ($('#g-recaptcha-response').val() != '' && $('#g-recaptcha-response').val() != undefined) {
#                 clearInterval(compruebaRecaptcha);
#                 $('#recaptcha').removeAttr("disabled");
#                 }
#                 }, 1000);
#                 },
#                 error: function (result) {
#                 $('#reCaptchaLogin1').html('');
#                 }
#             });
#         }
#
#
#         $(function () {
#
#             if ($("#idcheckmantenimiento").val() == "Mantenimiento") {
#                 $("#idBotonlogin").click();
#             }
#
#
#             //$("#select-search").autocomplete({
#             //        source: "/Ajax/Search"
#             //    });
#
#             //ControlCookies();
#             //$('#btn-search').click(function () {
#             //    var gw2 = documente.getElementById('select-search');
#             //});
# //$("#select-search").autocomplete({
# //    source: function (request, response) {
# //        $.ajax({
# //            url: "/Home/Search", type: "POST", dataType: "json",
# //            //original code
# //            //data: { searchText: request.id, maxResults: 10 },
# //            //updated code; updated to request.term
# //            //and removed the maxResults since you are not using it on the server side
# //            data: { srch: request.term },
#
# //            success: function (data) {
# //                response($.map(data, function (item) {
# //                    //original code
# //                    //return { label: item.FullName, value: item.FullName, id: item.TagId };
# //                    //updated code
# //                    return { label: item.label, value: item.label, id: item.id };
# //                }));
# //            },
# //        select: function (event, ui) {
# //                //update the jQuery selector here to your target hidden field
# //            $("input[type=hidden]").val(ui.item.id);
# //        }
# //        });
# //    },
# //});
#
#             //var availableTags = ["ActionScript", "AppleScript", "Asp", "BASIC", "C", "C++", "Clojure", "COBOL", "ColdFusion", "Erlang", "Fortran", "Groovy", "Haskell", "Java", "JavaScript", "Lisp", "Perl", "PHP", "Python", "Ruby", "Scala", "Scheme"];
#             //$("#select-search").autocomplete({ source: availableTags });
#             //$("#select-search").on("keyup", function () {
#             //    var term = $(this).val();
#             //    $(this).autocomplete("destroy");
#             //    console.log(term);
#             //    $(this).autocomplete({ source: availableTags });
#
#             //});
#             //var miResponse;
#
#             $("#select-search").autocomplete({
#                 source: function (request, response) {
#                     //console.log(request);
#                     console.log(response);
#                     $.ajax( {
#                       url: "/Home/Search",
#                       dataType: "json",
#                       type: "POST",
#                       data: {
#                         term: request.term
#                       },
#                         success: function (data) {
#                             //alert(data);
#                             console.log(data);
#                             response( data );
#                         },
#                         error: function (err) {
#                             //alert("error");
#                             console.log(err);
#                         }
#                     });
#                   },
#                     minLength: 2
#             });
#
#            $('#modalpres').click(function () {
#                     bootbox.dialog({
#                             title: 'Por favor, introduzca el localizador del presupuesto:',
#                             message: "<input type='text' id='inputLocalicer' class='form-control' placeholder='XAAA1A1-00' /> </br> <p style='font-size:16px;'>O accede al <a href='/Agency/ListBookings'> <b>listado de reservas</b>.</a></p>",
#                             buttons: {
#                                 ok: {
#                                     label: "Enviar",
#                                     className: 'btn-info',
#                                     callback: function (item) {
#                                         var xd = document.getElementById('inputLocalicer');
#                                         var token = '';//document.getElementById('usuToken').value;
#                                         var link = 'https://reservas-online.es.tui.com/b2b/redirectionDeepLinkQuote.jsf?quoteReference=' + xd.value + '&UP=' + token;
#                                         if (xd.value)
#                                             window.location.href = link;  //redirige
#                                             //window.location.replace(link); //otra pestaña
#                                     }
#                                 }
#                             }
#                         });
#            });
#
#
#         });
#
#
#          function goToBooking() {
#              var loc = document.getElementById("idLoc").value;
#              if (loc) {
#                  document.getElementById("buscaReserva").href = "/Agency/BookingDetail/" + loc;
#                  document.getElementById("buscaReserva").click();
#              }
#              //else if (loc2) {
#              //    var link = "/Agency/BookingDetail?id=" + loc2;
#              //    window.open(link, "_self");
#              //}
#             //$.ajax({
#             //    type: "POST",
#             //    url: urlGetLocs + "?id="+loc,
#             //    success: function(msg) {
#             //    }
#             //});
#         }
#
#
#          function buscaViajeFreetext() {
#             var loc = document.getElementById("idBuscViajeDash").value;
#
#              console.log(loc);
#              if (loc) {
#                  var link = "/viajes?freeText=" + loc;
#                  window.open(link,"_self");
#              }
#              //else {
#              //    swal({ "Por favor, introduzca algún destino"});
#              //}
#
#             //$.ajax({
#             //    type: "POST",
#             //    url: urlGetLocs + "?id="+loc,
#             //    success: function(msg) {
#             //    }
#             //});
#         }
#
#
#     function goToQuotation() {
#         debugger;
#         var presu1 = document.getElementById('inputPresupuesto');
#             var presu2 = document.getElementById('inputPresupuestoDash');
#             var quotationId = "";
#             if (presu1.value || presu2.value) {
#                 if (presu1.value) {
#                     quotationId = presu1.value;
#                 } else if (presu2.value) {
#                     quotationId = presu2.value;
#                 }
#                 var link = "/Agency/QuoteInfo" + "?quotationId=" + quotationId;
#                 window.open(link, "_blank");
#             }
#     }
#
#         function chekKey(e) {
#             //See notes about 'which' and 'key'
#             if (e.keyCode == 13) { //si presiona enter
#                 goToBooking();
#             }
#         }
#         function chekKeyPresu(e) {
#             //See notes about 'which' and 'key'
#             if (e.keyCode == 13) { //si presiona enter
#                 goToQuotation();
#             }
#         }
#
#         function cambiaImgTV(element) {
#             var tipovviaje_back = element.id;
#             var default_img = "/images/demo/tipos-viaje.jpg";
#             if (tipovviaje_back) {
#                 $('#img_tipoViaje').attr('src', tipovviaje_back);
#                 //document.getElementById('img_tipoViaje').src == tipovviaje_back;
#                 //console.log(document.getElementById('img_tipoViaje').src);
#             }
#             //else {
#             //    document.getElementById('img_tipoViaje').src = default_img;
#             //}
#         }
#
#         //Modal contáctanos inicio
#         $("#btnClose").click(function () {
#             $("#modalContacto").hide();
#         });
#         function cambiarTexto() {
#             $("#labelUno").html("<a class='labelContacto linkContacto' href='mailto:info.ts@tui.com'>info.ts@tui.com</a>");
#             $("#labelDos").html("<a class='labelContacto linkContacto' href='tel://+34917582828'>+34 91 758 2828</a>");
#         }
#
#         //$(".b_packages").click(function () {   //Angel 15/04/2020 - Lo comento por que está haciendo que fallen todos los enlaces con target = "_blank" de la web"
#         //    var location = $(this).find("a").attr("href");
#
#         //    if (location != undefined && location != null) {
#         //        window.location = location;
#         //    }
#
#         //    return false;
#         //});
#
#         ///////////////////////////// COOKIES  (ANTIGUO)//////////////////////////////
#         //function ControlCookies() {
#         //    if (localStorage.controlcookie > 0) {
#         //        console.log(localStorage.controlcookie);
#         //        $('#modalCookies').hide();
#         //    } else
#         //         $('#modalCookies').show();
#
#         //}
#         //function aceptaCookies() {
#         //    // si variable no existe se crea (al clicar en Aceptar)
#         //    localStorage.controlcookie = (localStorage.controlcookie || 0);
#         //    // incrementamos cuenta de la cookie
#         //    localStorage.controlcookie++;
#         //    //cierro mensaje
#         //      $('#modalCookies').hide();
#         //    console.log("El usuario aceptó las cookies");
#         //}
#         //function CancelarCookies() {  //por el momento no lo estamos usando
# 	       // console.log("rrr")
#         //    cookies.style.display = 'none';
#         //}
#
#         //-----
#          //var settings = {
#          //       message: 'Esta web utiliza cookies para mejorar la experiencia y proporcionar funcionalidades adicionales.. <b> ás información ',
#          //       moreLinkLabel: 'aquí.</b>',
#          //       messageMaxHeightPercent: 30,
#          //       moreLink: '/Content/View/politica-privacidad/',
#          //       delay: 1000,
#          //       allowAdvancedOptions: true,
#          //       OnAccept: function () {
#          //           console.log('Yay! User accepted your cookies window!');
#          //           console.log('User preferences');
#          //           var preferences = $.fn.bsgdprcookies.GetUserPreferences();
#          //           console.log(preferences);
#
#          //       }
#          //   }
#
#          //   $(document).ready(function () {
#          //       $('body').bsgdprcookies(settings);
#          //       $("#modalCookies").on("show", function () {
#          //       $('#cookiesBtn').on('click', function () {
#          //           $('body').bsgdprcookies(settings, 'reinit');
#          //       });
#          //   });
#
#
#         /////////////////////////////////////////////////////////////////////////////
#
# </script>
# <style>
#
#         .grecaptcha-badge {
#             display: none !important;
#         }
#
#         .carousel-control {
#             width: 4%;
#         }
#
#             .carousel-control.left, .carousel-control.right {
#                 margin-left: 15px;
#                 background-image: none;
#             }
#
#         @media (max-width: 475px) {
#             .degradado {
#                 padding-top: 25%;
#             }
#         }
#
#         @media (min-width: 475px) and (max-width: 767px ) {
#             .degradado {
#                 padding-top: 50%;
#             }
#         }
#
#         @media (max-width: 767px) { /*Mobile*/
#             .carousel-inner .active.left {
#                 left: -100%;
#             }
#
#             .carousel-inner .next {
#                 left: 100%;
#             }
#
#             .carousel-inner .prev {
#                 left: -100%;
#             }
#
#             .active > div {
#                 /*display: none;*/
#             }
#
#                 .active > div:first-child {
#                     display: block;
#                 }
#
#             .search-view-mobile {
#                 display: initial;
#             }
#
#             .search-view-web {
#                 display: none;
#             }
#
#             .filter-view-mobile {
#                 display: initial;
#             }
#
#             .filter-view-web {
#                 display: none;
#             }
#             /*//modal cookies*/
#             .cc_dialog.interstitial {
#                 right: 5vw;
#                 top: 5vh;
#                 left: 5vw;
#                 max-width: 90%;
#                 position: fixed;
#                 max-height: 90%;
#                 overflow: auto;
#             }
#
#             .lista-flotante {
#                 display: none;
#             }
#             /*.mobile-scrollable {
#                 display: block;
#                 overflow-x: auto;
#             }*/
#         }
#
#         @media (min-width: 767px) and (max-width: 992px ) {
#             .carousel-inner .active.left {
#                 left: -50%;
#             }
#
#             .carousel-inner .next {
#                 left: 50%;
#             }
#
#             .carousel-inner .prev {
#                 left: -50%;
#             }
#
#             .active > div {
#                 /*display: none;*/
#             }
#
#                 .active > div:first-child {
#                     display: block;
#                 }
#
#                     .active > div:first-child + div {
#                         display: block;
#                     }
#
#             .search-view-mobile {
#                 display: initial;
#             }
#
#             .search-view-web {
#                 display: none;
#             }
#
#             .filter-view-mobile {
#                 display: initial;
#             }
#
#             .filter-view-web {
#                 display: none;
#             }
#
#             .degradado {
#                 padding-top: 0%;
#             }
#
#             .lista-flotante {
#                 display: block;
#             }
#         }
#
#         @media (min-width: 992px ) {
#             .carousel-inner .active.left {
#                 left: -25%;
#             }
#
#             .carousel-inner .next {
#                 left: 25%;
#             }
#
#             .carousel-inner .prev {
#                 left: -25%;
#             }
#
#             .filter-view-mobile {
#                 display: none;
#             }
#
#             .filter-view-web {
#                 display: block;
#             }
#         }
#
#         /*@media print
#         {
#             .no-print, .no-print *
#             {
#                 display: none !important;
#             }
#         }*/
#
#         .swal-wide-auto {
#             width: auto !important;
#         }
#
#         .swal-tui-blue {
#             padding: 2%;
#             background-color: #70cbf4 !important;
#             color: white;
#             font-family: 'TUITypeLt', sans-serif !important;
#             font-size: 18px !important;
#             text-align: justify;
#             width: 32%;
#         }
#
#         /*.mobile-scrollable {
#                 display: block;
#                 overflow-x: auto;
#             }*/
#
#     </style>
# </link></link></body>
# </html>

# %%
#Vamos a extraer todas los contenidos de la clase hot-page2-alp-tit

clase_hot_pag2_alp_tit=sopa_argentina.find_all("div", {"class":"hot-page2-alp-tit"})
print(len(clase_hot_pag2_alp_tit))
Continente= clase_hot_pag2_alp_tit[0].get_text().strip("\n").split("-")[0]
Pais= clase_hot_pag2_alp_tit[0].get_text().strip("\n").split("-")[1].split("\n")[0]
print(Continente)
print(Pais)
# Out:
# 1
# Europa
# Alemania
